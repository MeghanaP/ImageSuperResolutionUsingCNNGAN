# %%
from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/MIE1516 Project/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
import cv2
import h5py
import numpy
import math
import skimage
from math import log10, sqrt 
from skimage.metrics import structural_similarity, peak_signal_noise_ratio

# %%
DATA_PATH = root_path + "/DIV2K_train_HR"
LR_DATA_PATH = root_path + "/DIV2K_train_LR_bicubic_X2/"
TEST_PATH = root_path + "/DIV2K_valid_HR/"
SAMPLE_IMAGE_TEST_PATH = root_path + "/DIV2K_valid_HR_sample/"

# %%
import scipy
from skimage import transform, io
import imageio
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

class DataLoader():
    def __init__(self, dataset_name, img_res=(128, 128)):
        self.dataset_name = dataset_name
        self.img_res = img_res

    def load_data(self, batch_size=1, is_testing=False, is_random=True):
        data_type = "train" if not is_testing else "test"
        
        path = glob('%s/*' % (self.dataset_name))

        if(is_random == True):
          batch_images = np.random.choice(path, size=batch_size)
        else:
          batch_images = path[0:batch_size]

        imgs_hr = []
        imgs_lr = []
        for img_path in batch_images:
            img = self.imread(img_path)

            h, w = self.img_res
            low_h, low_w = int(h / 4), int(w / 4)

            img_hr = transform.resize(img, self.img_res)
            img_lr = transform.resize(img, (low_h, low_w))

            # If training => do random flip
            if not is_testing and np.random.random() < 0.5:
                img_hr = np.fliplr(img_hr)
                img_lr = np.fliplr(img_lr)

            imgs_hr.append(img_hr)
            imgs_lr.append(img_lr)

        imgs_hr = np.array(imgs_hr) / 127.5 - 1.
        imgs_lr = np.array(imgs_lr) / 127.5 - 1.
        print(imgs_hr.shape)
        print(imgs_lr.shape)
        return imgs_hr, imgs_lr


    def imread(self, path):
        return imageio.imread(path, pilmode='RGB').astype(np.float)

# %%
class ImageMetrics():
  def __init__(self):
    self.name = "Metric for Image"
  
  def print_metrics(self, reference, generated):
    self.reference = (reference)*255.0
    self.generated = (generated)*255.0
    assert self.reference.shape == self.generated.shape
    psnr_score, ssim_score = self.psnr(), self.ssim()
    print("PSNR: %.4f SSIM: %.4f" % (psnr_score, ssim_score))
    return psnr_score, ssim_score

  #Link: https://dsp.stackexchange.com/questions/38065/peak-signal-to-noise-ratio-psnr-in-python-for-an-image
  def psnr(self):
    mse = np.mean((self.reference-self.generated)**2)
    if(mse == 0):
      mse = 100
    MAX_PIXEL = 255.0
    psnr_score = 20*log10(MAX_PIXEL/sqrt(mse))
    return psnr_score

  #Link: https://scikit-image.org/docs/dev/api/skimage.metrics.html#skimage.metrics.structural_similarity
  def ssim(self):
    (ssim_score, difference) = structural_similarity(self.reference, self.generated, multichannel= True, gaussian_weights= True, full=True)
    return ssim_score

# %%
"""
Super-resolution of CelebA using Generative Adversarial Networks.

The dataset can be downloaded from: https://www.dropbox.com/sh/8oqt9vytwxb3s4r/AADIKlz8PR9zr6Y20qbkunrba/Img/img_align_celeba.zip?dl=0

Instrustion on running the script:
1. Download the dataset from the provided link
2. Save the folder 'img_align_celeba' to 'datasets/'
4. Run the sript using command 'python srgan.py'
"""

from __future__ import print_function, division
import scipy
# !pip install git+https://www.github.com/keras-team/keras-contrib.git

# %tensorflow_version 1.x


from keras.datasets import mnist
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate
from keras.layers import BatchNormalization, Activation, ZeroPadding2D, Add
from keras.layers.advanced_activations import PReLU, LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.applications import VGG19
from keras.models import Sequential, Model
from keras.optimizers import Adam

import tensorflow as tf
import datetime
import matplotlib.pyplot as plt
import sys
#from data_loader import DataLoader
import numpy as np
import os
from collections import defaultdict
try:
    import cPickle as pickle
except ImportError:
    import pickle

import keras.backend as K

class SRGAN_MSE():
    def __init__(self):
        # Input shape
        self.channels = 3
        self.lr_height = 64                 # Low resolution height
        self.lr_width = 64                  # Low resolution width
        self.lr_shape = (self.lr_height, self.lr_width, self.channels)
        self.hr_height = self.lr_height*4   # High resolution height
        self.hr_width = self.lr_width*4     # High resolution width
        self.hr_shape = (self.hr_height, self.hr_width, self.channels)

        # Number of residual blocks in the generator
        self.n_residual_blocks = 16

        optimizer = Adam(0.0002, 0.5)

        # We use a pre-trained VGG19 model to extract image features from the high resolution
        # and the generated high resolution images and minimize the mse between them
        # self.vgg = self.build_vgg()
        # self.vgg.trainable = False
        # self.vgg.compile(loss='mse',
        #     optimizer=optimizer,
        #     metrics=['accuracy'])

        # Configure data loader
        self.save_path_name = root_path
        self.dataset_name = DATA_PATH
        self.test_dataset_name = TEST_PATH
        self.sample_test_dataset_name = SAMPLE_IMAGE_TEST_PATH
        self.data_loader = DataLoader(dataset_name=self.dataset_name,
                                      img_res=(self.hr_height, self.hr_width))
        self.test_data_loader = DataLoader(dataset_name=self.test_dataset_name,
                                      img_res=(self.hr_height, self.hr_width))
        self.sample_test_data_loader = DataLoader(dataset_name=self.sample_test_dataset_name,
                                      img_res=(self.hr_height, self.hr_width))
        self.metrics = ImageMetrics()
        
        os.makedirs('%s/SRGAN_MSE' % self.save_path_name, exist_ok=True)
        os.makedirs('%s/SRGAN_MSE/checkpoints' % self.save_path_name, exist_ok=True)
        os.makedirs('%s/SRGAN_MSE/sample_image_outputs' % self.save_path_name, exist_ok=True)

        self.model_gen_path = self.save_path_name + "SRGAN_MSE/checkpoints/model_mse_gen_april11.h5"
        self.model_disc_path = self.save_path_name + "SRGAN_MSE/checkpoints/model_mse_disc_april11.h5"
        self.model_combined_path = self.save_path_name + "SRGAN_MSE/checkpoints/model_mse_combined_april11.h5"
        self.sample_images_path = self.save_path_name + "SRGAN_MSE/sample_image_outputs"
        self.history_loss_accuracy_path = self.save_path_name + "SRGAN_MSE/srgan-mse-history.pkl"

        # Calculate output shape of D (PatchGAN)
        patch = int(self.hr_height / 2**4)
        self.disc_patch = (patch, patch, 1)

        # Number of filters in the first layer of G and D
        self.gf = 64
        self.df = 64

        # Build and compile the discriminator
        self.discriminator = self.build_discriminator()
        self.discriminator.compile(loss='mse',
            optimizer=optimizer,
            metrics=['accuracy'])

        # Build the generator
        self.generator = self.build_generator()

        # High res. and low res. images
        img_hr = Input(shape=self.hr_shape)
        img_lr = Input(shape=self.lr_shape)

        # Generate high res. version from low res.
        fake_hr = self.generator(img_lr)

        # Extract image features of the generated img
        #fake_features = self.vgg(fake_hr)

        # For the combined model we will only train the generator
        self.discriminator.trainable = False

        # Discriminator determines validity of generated high res. images
        validity = self.discriminator(fake_hr)

        self.combined = Model([img_lr,img_hr], [fake_hr, validity])
        self.combined.compile(loss=['mse','binary_crossentropy'],
                              loss_weights=[1,1e-3],
                              optimizer=optimizer)


    def build_vgg(self):
        """
        Builds a pre-trained VGG19 model that outputs image features extracted at the
        third block of the model
        """
        vgg = VGG19(weights="imagenet")
        # Set outputs to outputs of last conv. layer in block 3
        # See architecture at: https://github.com/keras-team/keras/blob/master/keras/applications/vgg19.py
        vgg.outputs = [vgg.layers[9].output]

        img = Input(shape=self.hr_shape)

        # Extract image features
        img_features = vgg(img)

        return Model(img, img_features)

    def build_generator(self):

        def residual_block(layer_input, filters):
            """Residual block described in paper"""
            d = Conv2D(filters, kernel_size=3, strides=1, padding='same')(layer_input)
            d = Activation('relu')(d)
            d = BatchNormalization(momentum=0.8)(d)
            d = Conv2D(filters, kernel_size=3, strides=1, padding='same')(d)
            d = BatchNormalization(momentum=0.8)(d)
            d = Add()([d, layer_input])
            return d

        def deconv2d(layer_input):
            """Layers used during upsampling"""
            u = UpSampling2D(size=2)(layer_input)
            u = Conv2D(256, kernel_size=3, strides=1, padding='same')(u)
            u = Activation('relu')(u)
            return u

        # Low resolution image input
        img_lr = Input(shape=self.lr_shape)

        # # Pre-residual block
        # c1 = Conv2D(64, kernel_size=9, strides=1, padding='same')(img_lr)
        # c1 = Activation('relu')(c1)

        # # Propogate through residual blocks
        # r = residual_block(c1, self.gf)
        # for _ in range(self.n_residual_blocks - 1):
        #     r = residual_block(r, self.gf)

        # # Post-residual block
        # c2 = Conv2D(64, kernel_size=3, strides=1, padding='same')(r)
        # c2 = BatchNormalization(momentum=0.8)(c2)
        # c2 = Add()([c2, c1])

        # # Upsampling
        # u1 = deconv2d(c2)
        # u2 = deconv2d(u1)

        # # Generate high resolution output
        # gen_hr = Conv2D(self.channels, kernel_size=9, strides=1, padding='same', activation='tanh')(u2)
        c1 = Conv2D(128, kernel_size=9, strides=1, padding='same')(img_lr)
        c1 = Activation('relu')(c1)
        c2 = Conv2D(64, kernel_size=3, strides=1, padding='same')(c1)
        c2 = Activation('relu')(c2)
        c3 = Conv2D(3, kernel_size=5, strides=1, padding='same')(c2)
        c3 = Activation('linear')(c3)
        u1 = deconv2d(c3)
        u2 = deconv2d(u1)
        gen_hr = Conv2D(self.channels, kernel_size=9, strides=1, padding='same', activation='tanh')(u2)
        
        #gen_hr = Reshape(self.hr_shape)

        model_gen = Model(img_lr, gen_hr)
        print(model_gen.summary())
        return model_gen

    def build_discriminator(self):

        def d_block(layer_input, filters, strides=1, bn=True):
            """Discriminator layer"""
            d = Conv2D(filters, kernel_size=3, strides=strides, padding='same')(layer_input)
            d = LeakyReLU(alpha=0.2)(d)
            if bn:
                d = BatchNormalization(momentum=0.8)(d)
            return d

        # Input img
        d0 = Input(shape=self.hr_shape)

        d1 = d_block(d0, self.df, bn=False)
        d2 = d_block(d1, self.df, strides=2)
        d3 = d_block(d2, self.df*2)
        d4 = d_block(d3, self.df*2, strides=2)
        d5 = d_block(d4, self.df*4)
        d6 = d_block(d5, self.df*4, strides=2)
        d7 = d_block(d6, self.df*8)
        d8 = d_block(d7, self.df*8, strides=2)

        d9 = Dense(self.df*16)(d8)
        d10 = LeakyReLU(alpha=0.2)(d9)
        validity = Dense(1, activation='sigmoid')(d10)

        model_disc = Model(d0, validity)
        print(model_disc.summary())
        return model_disc

    def train(self, epochs, batch_size=1, sample_interval=50):

        start_time = datetime.datetime.now()

        if(os.path.exists(self.model_gen_path)):
          print("I am here")
          self.generator.load_weights(self.model_gen_path)

        if(os.path.exists(self.model_disc_path)):
          print("I am here")
          self.discriminator.load_weights(self.model_disc_path)
        
        if(os.path.exists(self.model_combined_path)):
          print("I am here")
          self.combined.load_weights(self.model_combined_path)

        train_dict = defaultdict(list)
        test_dict = defaultdict(list)
        sample_imgs_hr, sample_imgs_lr = self.sample_test_data_loader.load_data(batch_size=2, is_testing=True, is_random=False)
        for epoch in range(epochs):

            # ----------------------
            #  Train Discriminator
            # ----------------------

            # Sample images and their conditioning counterparts
            imgs_hr, imgs_lr = self.data_loader.load_data(batch_size)
            # self.discriminator.trainable = True
            # From low res. image generate high res. version
            fake_hr = self.generator.predict(imgs_lr)

            valid = np.ones((batch_size,) + self.disc_patch)
            fake = np.zeros((batch_size,) + self.disc_patch)

            # Train the discriminators (original images = real / generated = Fake)
            d_loss_real = self.discriminator.train_on_batch(imgs_hr, valid)
            d_loss_fake = self.discriminator.train_on_batch(fake_hr, fake)
            d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

            # ------------------
            #  Train Generator
            # ------------------

            # Sample images and their conditioning counterparts
            imgs_hr, imgs_lr = self.data_loader.load_data(batch_size)
           
            # The generators want the discriminators to label the generated images as real
            valid = np.ones((batch_size,) + self.disc_patch)

            # Extract ground truth image features using pre-trained VGG19 model
            #image_features = self.vgg.predict(imgs_hr)

            # Train the generators
            g_loss = self.combined.train_on_batch([imgs_lr,imgs_hr], [imgs_hr,valid])
            
            print("Training Losses")
            print("Discriminator Real + Fake => Training Loss: %.4f Training Accuracy: %.4f" %(d_loss[0], d_loss[1]))
            train_dict["discriminator"].append(d_loss)

            print("Generator (Combined) => Training Content Loss: %.4f Adverserial Loss: %.4f Perceptual Loss: %.4f" %(g_loss[1], g_loss[2], g_loss[0]))
            train_dict["generator"].append(g_loss)

            # ----------------------
            #  Test Discriminator
            # ----------------------

            # Sample images and their conditioning counterparts
            imgs_hr, imgs_lr = self.test_data_loader.load_data(batch_size, is_testing=True)
            # self.discriminator.trainable = True
            # From low res. image generate high res. version
            fake_hr = self.generator.predict(imgs_lr)

            valid = np.ones((batch_size,) + self.disc_patch)
            fake = np.zeros((batch_size,) + self.disc_patch)

            # Train the discriminators (original images = real / generated = Fake)
            test_d_loss_real = self.discriminator.test_on_batch(imgs_hr, valid)
            test_d_loss_fake = self.discriminator.test_on_batch(fake_hr, fake)
            test_d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

            # ------------------
            #  Test Generator
            # ------------------

            # Sample images and their conditioning counterparts
            imgs_hr, imgs_lr = self.test_data_loader.load_data(batch_size, is_testing=True)
           
            # The generators want the discriminators to label the generated images as real
            valid = np.ones((batch_size,) + self.disc_patch)

            # Extract ground truth image features using pre-trained VGG19 model
            #image_features = self.vgg.predict(imgs_hr)

            # Train the generators
            test_g_loss = self.combined.test_on_batch([imgs_lr,imgs_hr], [imgs_hr,valid])

            print("Testing Losses")
            print("Discriminator Real + Fake => Testing Loss: %.4f Testing Accuracy: %.4f" %(test_d_loss[0], test_d_loss[1]))
            test_dict["discriminator"].append(test_d_loss)

            print("Generator (Combined) => Testing Content Loss: %.4f Adverserial Loss: %.4f Perceptual Loss: %.4f" %(test_g_loss[1], test_g_loss[2], test_g_loss[0]))
            test_dict["generator"].append(test_g_loss)

            elapsed_time = datetime.datetime.now() - start_time
            # Plot the progress
            print ("%d time: %s" % (epoch, elapsed_time))

            self.generator.save_weights(self.model_gen_path)
            self.discriminator.save_weights(self.model_disc_path)
            self.combined.save_weights(self.model_combined_path)
            # If at save interval => save generated image samples
            if epoch % sample_interval == 0:
                self.sample_images(epoch,sample_imgs_hr, sample_imgs_lr)

        with open(self.history_loss_accuracy_path, 'wb') as f:
          pickle.dump({'train': train_dict, 'test': test_dict}, f)

    def sample_images(self, epoch, sample_imgs_hr=None, sample_imgs_lr=None):
        #os.makedirs('images/%s' % self.dataset_name, exist_ok=True)
        r, c = 2, 3

        if(sample_imgs_hr is None or sample_imgs_lr is None):
          imgs_hr, imgs_lr = self.test_data_loader.load_data(batch_size=2, is_testing=True)
        else:
          imgs_hr, imgs_lr = sample_imgs_hr,sample_imgs_lr

        fake_hr = self.generator.predict(imgs_lr)

        # Rescale images 0 - 1
        imgs_lr = 0.5 * imgs_lr + 0.5
        fake_hr = 0.5 * fake_hr + 0.5
        imgs_hr = 0.5 * imgs_hr + 0.5

        # Save generated images and the high resolution originals
        titles = ['LR Original','Generated', 'Original']
        fig, axs = plt.subplots(r, c)
        cnt = 0
        for row in range(r):
            psnr_score, ssim_score = self.metrics.print_metrics(reference=imgs_hr[row][2], generated=fake_hr[row][1])
            for col, image in enumerate([imgs_lr, fake_hr, imgs_hr]):
                if(row == 0):
                  if(titles[col] == 'Generated'):
                    col_title = "Generated \n PSNR: %.4f SSIM: %.4f" % (psnr_score, ssim_score)
                  else:
                    col_title = titles[col]+ "\n"
                else:
                  if(titles[col] == 'Generated'):
                    col_title = "PSNR: %.4f SSIM: %.4f" % (psnr_score, ssim_score)
                  else:
                    col_title = "\n"
                axs[row, col].imshow(image[row])
                axs[row, col].set_title(col_title)
                axs[row, col].axis('off')
            cnt += 1
        fig.savefig("%s/%d.png" % (self.sample_images_path, epoch))
        plt.close()

        # Save low resolution images for comparison
        if((epoch == 0 and (sample_imgs_hr is not None or sample_imgs_lr is not None)) or (sample_imgs_hr is None or sample_imgs_lr is None)):
          for i in range(r):
              fig = plt.figure()
              plt.imshow(imgs_lr[i])
              fig.savefig('%s/%d_lowres%d.png' % (self.sample_images_path, epoch, i))
              plt.close()

if __name__ == '__main__':
    tf.reset_default_graph()
    try:
        del gan
    except:
        pass
    K.clear_session()

    
    graph = tf.get_default_graph()

    with graph.as_default():
      gan = SRGAN_MSE()
      gan.train(epochs=201, batch_size=10, sample_interval=50)
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-r4uw14_e
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-r4uw14_e
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.3.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.18.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.12.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.0)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101064 sha256=8942ccb685d42ec00c1218927310c7e2e6578527212e5a7ec4103876ab4c4681
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lkkk1kx6/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 64)      1792
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128, 128, 64)      0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 128)     73856
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 128, 128, 128)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 128, 128)     512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 128)       147584
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64, 64, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 256)       295168
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64, 64, 256)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 64, 256)       1024
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 512)       1180160
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 32, 32, 512)       0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 512)       2048
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 512)       2359808
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 16, 16, 512)       0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 512)       2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 16, 16, 1024)      525312
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 16, 16, 1024)      0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16, 16, 1)         1025
# =================================================================
# Total params: 5,219,137
# Trainable params: 5,215,425
# Non-trainable params: 3,712
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 64, 64, 128)       31232
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 64, 64, 64)        73792
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 64, 64, 3)         4803
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 64, 3)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 128, 128, 3)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 128, 256)     7168
# _________________________________________________________________
# activation_4 (Activation)    (None, 128, 128, 256)     0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 256, 256, 256)     0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 256, 256, 256)     590080
# _________________________________________________________________
# activation_5 (Activation)    (None, 256, 256, 256)     0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 256, 256, 3)       62211
# =================================================================
# Total params: 769,286
# Trainable params: 769,286
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# (2, 256, 256, 3)
# (2, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3269 Training Accuracy: 0.4357
# Generator (Combined) => Training Content Loss: 0.3317 Adverserial Loss: 1.2276 Perceptual Loss: 0.3329
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3269 Testing Accuracy: 0.4357
# Generator (Combined) => Testing Content Loss: 0.3039 Adverserial Loss: 0.6902 Perceptual Loss: 0.3045
# 0 time: 0:01:39.798422
# /usr/local/lib/python3.6/dist-packages/skimage/metrics/_structural_similarity.py:108: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   im2[..., ch], **args)
# PSNR: 9.5474 SSIM: -0.0003
# PSNR: 14.9927 SSIM: -0.0006
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2842 Training Accuracy: 0.5342
# Generator (Combined) => Training Content Loss: 0.2921 Adverserial Loss: 1.4544 Perceptual Loss: 0.2935
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2842 Testing Accuracy: 0.5342
# Generator (Combined) => Testing Content Loss: 0.1764 Adverserial Loss: 0.6889 Perceptual Loss: 0.1771
# 1 time: 0:03:03.661728
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2470 Training Accuracy: 0.6330
# Generator (Combined) => Training Content Loss: 0.2482 Adverserial Loss: 1.7567 Perceptual Loss: 0.2499
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2470 Testing Accuracy: 0.6330
# Generator (Combined) => Testing Content Loss: 0.1929 Adverserial Loss: 0.6960 Perceptual Loss: 0.1935
# 2 time: 0:04:20.612221
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2748 Training Accuracy: 0.6080
# Generator (Combined) => Training Content Loss: 0.1379 Adverserial Loss: 1.8446 Perceptual Loss: 0.1398
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2748 Testing Accuracy: 0.6080
# Generator (Combined) => Testing Content Loss: 0.1466 Adverserial Loss: 0.6918 Perceptual Loss: 0.1473
# 3 time: 0:05:38.195304
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2987 Training Accuracy: 0.5045
# Generator (Combined) => Training Content Loss: 0.1588 Adverserial Loss: 1.8809 Perceptual Loss: 0.1606
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2987 Testing Accuracy: 0.5045
# Generator (Combined) => Testing Content Loss: 0.1032 Adverserial Loss: 0.6857 Perceptual Loss: 0.1039
# 4 time: 0:06:53.182711
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2222 Training Accuracy: 0.6627
# Generator (Combined) => Training Content Loss: 0.1492 Adverserial Loss: 1.9618 Perceptual Loss: 0.1512
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2222 Testing Accuracy: 0.6627
# Generator (Combined) => Testing Content Loss: 0.1228 Adverserial Loss: 0.6911 Perceptual Loss: 0.1235
# 5 time: 0:08:09.754465
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4591 Training Accuracy: 0.3230
# Generator (Combined) => Training Content Loss: 0.1396 Adverserial Loss: 2.1230 Perceptual Loss: 0.1417
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4591 Testing Accuracy: 0.3230
# Generator (Combined) => Testing Content Loss: 0.1243 Adverserial Loss: 0.7092 Perceptual Loss: 0.1250
# 6 time: 0:09:22.538300
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3445 Training Accuracy: 0.4496
# Generator (Combined) => Training Content Loss: 0.1554 Adverserial Loss: 2.2422 Perceptual Loss: 0.1576
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3445 Testing Accuracy: 0.4496
# Generator (Combined) => Testing Content Loss: 0.1242 Adverserial Loss: 0.6913 Perceptual Loss: 0.1249
# 7 time: 0:10:35.723637
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4128 Training Accuracy: 0.4020
# Generator (Combined) => Training Content Loss: 0.1018 Adverserial Loss: 1.6599 Perceptual Loss: 0.1035
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4128 Testing Accuracy: 0.4020
# Generator (Combined) => Testing Content Loss: 0.0841 Adverserial Loss: 0.6769 Perceptual Loss: 0.0848
# 8 time: 0:11:50.937563
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3143 Training Accuracy: 0.4949
# Generator (Combined) => Training Content Loss: 0.0915 Adverserial Loss: 1.8332 Perceptual Loss: 0.0933
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3143 Testing Accuracy: 0.4949
# Generator (Combined) => Testing Content Loss: 0.0835 Adverserial Loss: 0.7113 Perceptual Loss: 0.0842
# 9 time: 0:13:00.491162
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3406 Training Accuracy: 0.4410
# Generator (Combined) => Training Content Loss: 0.0679 Adverserial Loss: 1.9584 Perceptual Loss: 0.0699
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3406 Testing Accuracy: 0.4410
# Generator (Combined) => Testing Content Loss: 0.0984 Adverserial Loss: 0.7004 Perceptual Loss: 0.0991
# 10 time: 0:14:10.877363
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3290 Training Accuracy: 0.4658
# Generator (Combined) => Training Content Loss: 0.0799 Adverserial Loss: 1.7566 Perceptual Loss: 0.0817
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3290 Testing Accuracy: 0.4658
# Generator (Combined) => Testing Content Loss: 0.0769 Adverserial Loss: 0.7012 Perceptual Loss: 0.0776
# 11 time: 0:15:18.061666
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2646 Training Accuracy: 0.5672
# Generator (Combined) => Training Content Loss: 0.0785 Adverserial Loss: 2.0555 Perceptual Loss: 0.0806
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2646 Testing Accuracy: 0.5672
# Generator (Combined) => Testing Content Loss: 0.0703 Adverserial Loss: 0.6954 Perceptual Loss: 0.0710
# 12 time: 0:16:25.553089
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2754 Training Accuracy: 0.5650
# Generator (Combined) => Training Content Loss: 0.0802 Adverserial Loss: 1.9226 Perceptual Loss: 0.0821
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2754 Testing Accuracy: 0.5650
# Generator (Combined) => Testing Content Loss: 0.0715 Adverserial Loss: 0.6969 Perceptual Loss: 0.0722
# 13 time: 0:17:32.590473
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2135 Training Accuracy: 0.6699
# Generator (Combined) => Training Content Loss: 0.0620 Adverserial Loss: 1.7025 Perceptual Loss: 0.0637
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2135 Testing Accuracy: 0.6699
# Generator (Combined) => Testing Content Loss: 0.0819 Adverserial Loss: 0.6949 Perceptual Loss: 0.0826
# 14 time: 0:18:44.833048
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2353 Training Accuracy: 0.5828
# Generator (Combined) => Training Content Loss: 0.0732 Adverserial Loss: 1.9108 Perceptual Loss: 0.0751
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2353 Testing Accuracy: 0.5828
# Generator (Combined) => Testing Content Loss: 0.0835 Adverserial Loss: 0.6978 Perceptual Loss: 0.0842
# 15 time: 0:19:50.356641
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2418 Training Accuracy: 0.6250
# Generator (Combined) => Training Content Loss: 0.0830 Adverserial Loss: 1.8639 Perceptual Loss: 0.0848
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2418 Testing Accuracy: 0.6250
# Generator (Combined) => Testing Content Loss: 0.0536 Adverserial Loss: 0.7028 Perceptual Loss: 0.0543
# 16 time: 0:20:56.908732
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2123 Training Accuracy: 0.6820
# Generator (Combined) => Training Content Loss: 0.0530 Adverserial Loss: 1.9971 Perceptual Loss: 0.0550
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2123 Testing Accuracy: 0.6820
# Generator (Combined) => Testing Content Loss: 0.0936 Adverserial Loss: 0.6914 Perceptual Loss: 0.0943
# 17 time: 0:22:02.159500
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2928 Training Accuracy: 0.5412
# Generator (Combined) => Training Content Loss: 0.0939 Adverserial Loss: 1.5878 Perceptual Loss: 0.0955
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2928 Testing Accuracy: 0.5412
# Generator (Combined) => Testing Content Loss: 0.1040 Adverserial Loss: 0.6934 Perceptual Loss: 0.1047
# 18 time: 0:23:06.160375
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1873 Training Accuracy: 0.7074
# Generator (Combined) => Training Content Loss: 0.1078 Adverserial Loss: 2.1755 Perceptual Loss: 0.1099
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1873 Testing Accuracy: 0.7074
# Generator (Combined) => Testing Content Loss: 0.0648 Adverserial Loss: 0.6962 Perceptual Loss: 0.0655
# 19 time: 0:24:12.998948
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1567 Training Accuracy: 0.7941
# Generator (Combined) => Training Content Loss: 0.0730 Adverserial Loss: 1.7682 Perceptual Loss: 0.0748
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1567 Testing Accuracy: 0.7941
# Generator (Combined) => Testing Content Loss: 0.0762 Adverserial Loss: 0.6918 Perceptual Loss: 0.0769
# 20 time: 0:25:21.142582
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1643 Training Accuracy: 0.7658
# Generator (Combined) => Training Content Loss: 0.0669 Adverserial Loss: 2.0118 Perceptual Loss: 0.0689
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1643 Testing Accuracy: 0.7658
# Generator (Combined) => Testing Content Loss: 0.0657 Adverserial Loss: 0.6958 Perceptual Loss: 0.0664
# 21 time: 0:26:27.900898
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1800 Training Accuracy: 0.7551
# Generator (Combined) => Training Content Loss: 0.0489 Adverserial Loss: 1.8974 Perceptual Loss: 0.0508
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1800 Testing Accuracy: 0.7551
# Generator (Combined) => Testing Content Loss: 0.0638 Adverserial Loss: 0.6940 Perceptual Loss: 0.0645
# 22 time: 0:27:32.422000
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2531 Training Accuracy: 0.5760
# Generator (Combined) => Training Content Loss: 0.0556 Adverserial Loss: 2.1434 Perceptual Loss: 0.0577
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2531 Testing Accuracy: 0.5760
# Generator (Combined) => Testing Content Loss: 0.0599 Adverserial Loss: 0.6869 Perceptual Loss: 0.0606
# 23 time: 0:28:39.169120
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1460 Training Accuracy: 0.8021
# Generator (Combined) => Training Content Loss: 0.0514 Adverserial Loss: 2.3697 Perceptual Loss: 0.0537
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1460 Testing Accuracy: 0.8021
# Generator (Combined) => Testing Content Loss: 0.0641 Adverserial Loss: 0.6909 Perceptual Loss: 0.0648
# 24 time: 0:29:43.984892
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0776 Training Accuracy: 0.9412
# Generator (Combined) => Training Content Loss: 0.0600 Adverserial Loss: 2.2589 Perceptual Loss: 0.0623
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0776 Testing Accuracy: 0.9412
# Generator (Combined) => Testing Content Loss: 0.0531 Adverserial Loss: 0.6906 Perceptual Loss: 0.0537
# 25 time: 0:30:49.430546
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0614 Training Accuracy: 0.9617
# Generator (Combined) => Training Content Loss: 0.0526 Adverserial Loss: 2.6548 Perceptual Loss: 0.0553
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0614 Testing Accuracy: 0.9617
# Generator (Combined) => Testing Content Loss: 0.0578 Adverserial Loss: 0.6874 Perceptual Loss: 0.0585
# 26 time: 0:31:51.608099
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1318 Training Accuracy: 0.8234
# Generator (Combined) => Training Content Loss: 0.0453 Adverserial Loss: 2.8945 Perceptual Loss: 0.0482
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1318 Testing Accuracy: 0.8234
# Generator (Combined) => Testing Content Loss: 0.0537 Adverserial Loss: 0.6934 Perceptual Loss: 0.0544
# 27 time: 0:32:56.597738
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0758 Training Accuracy: 0.9396
# Generator (Combined) => Training Content Loss: 0.0688 Adverserial Loss: 2.5587 Perceptual Loss: 0.0714
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0758 Testing Accuracy: 0.9396
# Generator (Combined) => Testing Content Loss: 0.0734 Adverserial Loss: 0.6896 Perceptual Loss: 0.0741
# 28 time: 0:34:01.925409
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0400 Training Accuracy: 0.9982
# Generator (Combined) => Training Content Loss: 0.0509 Adverserial Loss: 2.4074 Perceptual Loss: 0.0533
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0400 Testing Accuracy: 0.9982
# Generator (Combined) => Testing Content Loss: 0.0597 Adverserial Loss: 0.6886 Perceptual Loss: 0.0604
# 29 time: 0:35:04.972731
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0232 Training Accuracy: 0.9992
# Generator (Combined) => Training Content Loss: 0.0543 Adverserial Loss: 2.8827 Perceptual Loss: 0.0572
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0232 Testing Accuracy: 0.9992
# Generator (Combined) => Testing Content Loss: 0.0523 Adverserial Loss: 0.6893 Perceptual Loss: 0.0530
# 30 time: 0:36:09.341032
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0223 Training Accuracy: 0.9977
# Generator (Combined) => Training Content Loss: 0.0612 Adverserial Loss: 2.8603 Perceptual Loss: 0.0641
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0223 Testing Accuracy: 0.9977
# Generator (Combined) => Testing Content Loss: 0.0651 Adverserial Loss: 0.6891 Perceptual Loss: 0.0658
# 31 time: 0:37:14.170249
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0195 Training Accuracy: 0.9977
# Generator (Combined) => Training Content Loss: 0.0497 Adverserial Loss: 3.1317 Perceptual Loss: 0.0529
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0195 Testing Accuracy: 0.9977
# Generator (Combined) => Testing Content Loss: 0.0458 Adverserial Loss: 0.6897 Perceptual Loss: 0.0465
# 32 time: 0:38:18.390668
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1196 Training Accuracy: 0.8447
# Generator (Combined) => Training Content Loss: 0.0610 Adverserial Loss: 2.9494 Perceptual Loss: 0.0640
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1196 Testing Accuracy: 0.8447
# Generator (Combined) => Testing Content Loss: 0.0720 Adverserial Loss: 0.6917 Perceptual Loss: 0.0727
# 33 time: 0:39:21.190065
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1536 Training Accuracy: 0.7725
# Generator (Combined) => Training Content Loss: 0.0556 Adverserial Loss: 3.2657 Perceptual Loss: 0.0588
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1536 Testing Accuracy: 0.7725
# Generator (Combined) => Testing Content Loss: 0.0554 Adverserial Loss: 0.6987 Perceptual Loss: 0.0561
# 34 time: 0:40:24.624403
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2266 Training Accuracy: 0.6646
# Generator (Combined) => Training Content Loss: 0.0543 Adverserial Loss: 2.3352 Perceptual Loss: 0.0566
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2266 Testing Accuracy: 0.6646
# Generator (Combined) => Testing Content Loss: 0.0532 Adverserial Loss: 0.6916 Perceptual Loss: 0.0539
# 35 time: 0:41:28.223782
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3170 Training Accuracy: 0.4445
# Generator (Combined) => Training Content Loss: 0.0622 Adverserial Loss: 2.6345 Perceptual Loss: 0.0648
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3170 Testing Accuracy: 0.4445
# Generator (Combined) => Testing Content Loss: 0.0620 Adverserial Loss: 0.6935 Perceptual Loss: 0.0627
# 36 time: 0:42:33.510408
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1663 Training Accuracy: 0.7512
# Generator (Combined) => Training Content Loss: 0.0591 Adverserial Loss: 2.1285 Perceptual Loss: 0.0612
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1663 Testing Accuracy: 0.7512
# Generator (Combined) => Testing Content Loss: 0.0507 Adverserial Loss: 0.6894 Perceptual Loss: 0.0514
# 37 time: 0:43:37.380335
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0576 Training Accuracy: 0.9799
# Generator (Combined) => Training Content Loss: 0.0434 Adverserial Loss: 2.4250 Perceptual Loss: 0.0458
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0576 Testing Accuracy: 0.9799
# Generator (Combined) => Testing Content Loss: 0.0483 Adverserial Loss: 0.6857 Perceptual Loss: 0.0490
# 38 time: 0:44:41.663631
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0397 Training Accuracy: 0.9916
# Generator (Combined) => Training Content Loss: 0.0501 Adverserial Loss: 2.8978 Perceptual Loss: 0.0530
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0397 Testing Accuracy: 0.9916
# Generator (Combined) => Testing Content Loss: 0.0481 Adverserial Loss: 0.6894 Perceptual Loss: 0.0488
# 39 time: 0:45:47.354544
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1568 Training Accuracy: 0.7793
# Generator (Combined) => Training Content Loss: 0.0481 Adverserial Loss: 2.3284 Perceptual Loss: 0.0504
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1568 Testing Accuracy: 0.7793
# Generator (Combined) => Testing Content Loss: 0.0527 Adverserial Loss: 0.6894 Perceptual Loss: 0.0534
# 40 time: 0:46:50.191979
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0315 Training Accuracy: 0.9875
# Generator (Combined) => Training Content Loss: 0.0419 Adverserial Loss: 2.9339 Perceptual Loss: 0.0449
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0315 Testing Accuracy: 0.9875
# Generator (Combined) => Testing Content Loss: 0.0484 Adverserial Loss: 0.6900 Perceptual Loss: 0.0491
# 41 time: 0:47:53.688732
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0193 Training Accuracy: 0.9998
# Generator (Combined) => Training Content Loss: 0.0442 Adverserial Loss: 3.3424 Perceptual Loss: 0.0475
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0193 Testing Accuracy: 0.9998
# Generator (Combined) => Testing Content Loss: 0.0402 Adverserial Loss: 0.6897 Perceptual Loss: 0.0409
# 42 time: 0:48:58.290004
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0561 Training Accuracy: 0.9752
# Generator (Combined) => Training Content Loss: 0.0502 Adverserial Loss: 2.2670 Perceptual Loss: 0.0525
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0561 Testing Accuracy: 0.9752
# Generator (Combined) => Testing Content Loss: 0.0610 Adverserial Loss: 0.6880 Perceptual Loss: 0.0617
# 43 time: 0:50:00.853524
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0368 Training Accuracy: 0.9850
# Generator (Combined) => Training Content Loss: 0.0436 Adverserial Loss: 3.3188 Perceptual Loss: 0.0469
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0368 Testing Accuracy: 0.9850
# Generator (Combined) => Testing Content Loss: 0.0830 Adverserial Loss: 0.6880 Perceptual Loss: 0.0837
# 44 time: 0:51:03.975781
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0135 Training Accuracy: 0.9998
# Generator (Combined) => Training Content Loss: 0.0598 Adverserial Loss: 3.0728 Perceptual Loss: 0.0629
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0135 Testing Accuracy: 0.9998
# Generator (Combined) => Testing Content Loss: 0.0551 Adverserial Loss: 0.6912 Perceptual Loss: 0.0558
# 45 time: 0:52:09.095067
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0218 Training Accuracy: 0.9867
# Generator (Combined) => Training Content Loss: 0.0767 Adverserial Loss: 3.4987 Perceptual Loss: 0.0802
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0218 Testing Accuracy: 0.9867
# Generator (Combined) => Testing Content Loss: 0.0454 Adverserial Loss: 0.6937 Perceptual Loss: 0.0461
# 46 time: 0:53:14.924423
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0303 Training Accuracy: 0.9814
# Generator (Combined) => Training Content Loss: 0.0520 Adverserial Loss: 2.9984 Perceptual Loss: 0.0550
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0303 Testing Accuracy: 0.9814
# Generator (Combined) => Testing Content Loss: 0.0584 Adverserial Loss: 0.6902 Perceptual Loss: 0.0591
# 47 time: 0:54:19.628277
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0145 Training Accuracy: 0.9971
# Generator (Combined) => Training Content Loss: 0.0631 Adverserial Loss: 2.5821 Perceptual Loss: 0.0657
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0145 Testing Accuracy: 0.9971
# Generator (Combined) => Testing Content Loss: 0.0569 Adverserial Loss: 0.6887 Perceptual Loss: 0.0575
# 48 time: 0:55:21.933332
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0085 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0494 Adverserial Loss: 2.8040 Perceptual Loss: 0.0522
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0085 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0609 Adverserial Loss: 0.6870 Perceptual Loss: 0.0616
# 49 time: 0:56:26.670335
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0054 Training Accuracy: 0.9994
# Generator (Combined) => Training Content Loss: 0.0504 Adverserial Loss: 3.0850 Perceptual Loss: 0.0535
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0054 Testing Accuracy: 0.9994
# Generator (Combined) => Testing Content Loss: 0.0522 Adverserial Loss: 0.6885 Perceptual Loss: 0.0529
# 50 time: 0:57:31.345171
# PSNR: 14.7774 SSIM: 0.0127
# PSNR: 17.7964 SSIM: 0.0557
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0124 Training Accuracy: 0.9998
# Generator (Combined) => Training Content Loss: 0.0450 Adverserial Loss: 2.7627 Perceptual Loss: 0.0477
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0124 Testing Accuracy: 0.9998
# Generator (Combined) => Testing Content Loss: 0.0592 Adverserial Loss: 0.6869 Perceptual Loss: 0.0599
# 51 time: 0:58:34.525915
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0279 Training Accuracy: 0.9844
# Generator (Combined) => Training Content Loss: 0.0428 Adverserial Loss: 3.5703 Perceptual Loss: 0.0463
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0279 Testing Accuracy: 0.9844
# Generator (Combined) => Testing Content Loss: 0.0449 Adverserial Loss: 0.6965 Perceptual Loss: 0.0456
# 52 time: 0:59:35.064784
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0239 Training Accuracy: 0.9834
# Generator (Combined) => Training Content Loss: 0.0484 Adverserial Loss: 3.4997 Perceptual Loss: 0.0519
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0239 Testing Accuracy: 0.9834
# Generator (Combined) => Testing Content Loss: 0.0492 Adverserial Loss: 0.6908 Perceptual Loss: 0.0499
# 53 time: 1:00:37.348683
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0909 Training Accuracy: 0.9189
# Generator (Combined) => Training Content Loss: 0.0566 Adverserial Loss: 2.9621 Perceptual Loss: 0.0596
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0909 Testing Accuracy: 0.9189
# Generator (Combined) => Testing Content Loss: 0.0483 Adverserial Loss: 0.7023 Perceptual Loss: 0.0490
# 54 time: 1:01:38.648393
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1291 Training Accuracy: 0.8621
# Generator (Combined) => Training Content Loss: 0.0437 Adverserial Loss: 3.1934 Perceptual Loss: 0.0469
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1291 Testing Accuracy: 0.8621
# Generator (Combined) => Testing Content Loss: 0.0394 Adverserial Loss: 0.6956 Perceptual Loss: 0.0401
# 55 time: 1:02:40.551444
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0194 Training Accuracy: 0.9980
# Generator (Combined) => Training Content Loss: 0.0460 Adverserial Loss: 3.6641 Perceptual Loss: 0.0497
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0194 Testing Accuracy: 0.9980
# Generator (Combined) => Testing Content Loss: 0.0406 Adverserial Loss: 0.6980 Perceptual Loss: 0.0413
# 56 time: 1:03:45.229427
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0948 Training Accuracy: 0.8977
# Generator (Combined) => Training Content Loss: 0.0519 Adverserial Loss: 3.3400 Perceptual Loss: 0.0552
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0948 Testing Accuracy: 0.8977
# Generator (Combined) => Testing Content Loss: 0.0414 Adverserial Loss: 0.6886 Perceptual Loss: 0.0420
# 57 time: 1:04:48.806639
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0402 Training Accuracy: 0.9637
# Generator (Combined) => Training Content Loss: 0.0477 Adverserial Loss: 2.7763 Perceptual Loss: 0.0505
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0402 Testing Accuracy: 0.9637
# Generator (Combined) => Testing Content Loss: 0.0444 Adverserial Loss: 0.6908 Perceptual Loss: 0.0451
# 58 time: 1:05:53.815942
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1027 Training Accuracy: 0.8705
# Generator (Combined) => Training Content Loss: 0.0336 Adverserial Loss: 3.8827 Perceptual Loss: 0.0375
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1027 Testing Accuracy: 0.8705
# Generator (Combined) => Testing Content Loss: 0.0458 Adverserial Loss: 0.6969 Perceptual Loss: 0.0465
# 59 time: 1:06:55.468724
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0975 Training Accuracy: 0.8990
# Generator (Combined) => Training Content Loss: 0.0343 Adverserial Loss: 3.2170 Perceptual Loss: 0.0375
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0975 Testing Accuracy: 0.8990
# Generator (Combined) => Testing Content Loss: 0.0384 Adverserial Loss: 0.6823 Perceptual Loss: 0.0391
# 60 time: 1:08:01.214601
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0372 Training Accuracy: 0.9707
# Generator (Combined) => Training Content Loss: 0.0406 Adverserial Loss: 3.3875 Perceptual Loss: 0.0440
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0372 Testing Accuracy: 0.9707
# Generator (Combined) => Testing Content Loss: 0.0459 Adverserial Loss: 0.6887 Perceptual Loss: 0.0466
# 61 time: 1:09:05.737819
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0067 Training Accuracy: 0.9992
# Generator (Combined) => Training Content Loss: 0.0424 Adverserial Loss: 3.2605 Perceptual Loss: 0.0457
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0067 Testing Accuracy: 0.9992
# Generator (Combined) => Testing Content Loss: 0.0402 Adverserial Loss: 0.6870 Perceptual Loss: 0.0408
# 62 time: 1:10:11.501663
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0030 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0319 Adverserial Loss: 2.9706 Perceptual Loss: 0.0349
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0030 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0405 Adverserial Loss: 0.6876 Perceptual Loss: 0.0412
# 63 time: 1:11:13.064595
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0084 Training Accuracy: 0.9996
# Generator (Combined) => Training Content Loss: 0.0398 Adverserial Loss: 3.4470 Perceptual Loss: 0.0432
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0084 Testing Accuracy: 0.9996
# Generator (Combined) => Testing Content Loss: 0.0467 Adverserial Loss: 0.6876 Perceptual Loss: 0.0474
# 64 time: 1:12:18.260509
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0026 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0352 Adverserial Loss: 4.0041 Perceptual Loss: 0.0392
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0026 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0472 Adverserial Loss: 0.6869 Perceptual Loss: 0.0478
# 65 time: 1:13:20.815099
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0042 Training Accuracy: 0.9998
# Generator (Combined) => Training Content Loss: 0.0368 Adverserial Loss: 3.4789 Perceptual Loss: 0.0403
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0042 Testing Accuracy: 0.9998
# Generator (Combined) => Testing Content Loss: 0.0418 Adverserial Loss: 0.6857 Perceptual Loss: 0.0425
# 66 time: 1:14:23.378762
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0033 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0368 Adverserial Loss: 3.7706 Perceptual Loss: 0.0406
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0033 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0467 Adverserial Loss: 0.6878 Perceptual Loss: 0.0474
# 67 time: 1:15:27.462058
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0029 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0545 Adverserial Loss: 3.3884 Perceptual Loss: 0.0579
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0029 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0547 Adverserial Loss: 0.6839 Perceptual Loss: 0.0554
# 68 time: 1:16:33.707448
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# ...
# 171 time: 3:02:04.913031
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0004 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0423 Adverserial Loss: 4.4683 Perceptual Loss: 0.0468
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0004 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0426 Adverserial Loss: 0.7020 Perceptual Loss: 0.0433
# 172 time: 3:03:05.448337
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0028 Training Accuracy: 0.9996
# Generator (Combined) => Training Content Loss: 0.0421 Adverserial Loss: 4.1052 Perceptual Loss: 0.0462
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0028 Testing Accuracy: 0.9996
# Generator (Combined) => Testing Content Loss: 0.0410 Adverserial Loss: 0.7047 Perceptual Loss: 0.0417
# 173 time: 3:04:04.848539
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0005 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0375 Adverserial Loss: 3.8834 Perceptual Loss: 0.0414
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0005 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0300 Adverserial Loss: 0.7058 Perceptual Loss: 0.0308
# 174 time: 3:05:03.737256
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0009 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0333 Adverserial Loss: 3.9592 Perceptual Loss: 0.0373
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0009 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0296 Adverserial Loss: 0.7013 Perceptual Loss: 0.0303
# 175 time: 3:06:03.842937
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0006 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0237 Adverserial Loss: 4.5734 Perceptual Loss: 0.0283
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0006 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0282 Adverserial Loss: 0.6955 Perceptual Loss: 0.0289
# 176 time: 3:07:01.554428
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0003 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0331 Adverserial Loss: 4.0900 Perceptual Loss: 0.0372
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0003 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0323 Adverserial Loss: 0.6960 Perceptual Loss: 0.0330
# 177 time: 3:07:59.905701
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0005 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0285 Adverserial Loss: 4.1099 Perceptual Loss: 0.0326
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0005 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0399 Adverserial Loss: 0.7057 Perceptual Loss: 0.0406
# 178 time: 3:08:56.974882
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0004 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0345 Adverserial Loss: 4.3398 Perceptual Loss: 0.0388
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0004 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0328 Adverserial Loss: 0.6988 Perceptual Loss: 0.0335
# 179 time: 3:09:58.283468
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0006 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0340 Adverserial Loss: 4.0078 Perceptual Loss: 0.0380
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0006 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0329 Adverserial Loss: 0.6972 Perceptual Loss: 0.0336
# 180 time: 3:10:56.298031
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0004 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0300 Adverserial Loss: 4.1805 Perceptual Loss: 0.0342
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0004 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0376 Adverserial Loss: 0.7025 Perceptual Loss: 0.0383
# 181 time: 3:11:53.915535
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0041 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0323 Adverserial Loss: 2.2565 Perceptual Loss: 0.0345
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0041 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0278 Adverserial Loss: 0.6962 Perceptual Loss: 0.0285
# 182 time: 3:12:52.816973
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0010 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0339 Adverserial Loss: 3.9455 Perceptual Loss: 0.0378
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0010 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0293 Adverserial Loss: 0.7021 Perceptual Loss: 0.0300
# 183 time: 3:13:51.664358
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0009 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0234 Adverserial Loss: 3.6248 Perceptual Loss: 0.0271
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0009 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0297 Adverserial Loss: 0.7015 Perceptual Loss: 0.0304
# 184 time: 3:14:52.591408
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0024 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0238 Adverserial Loss: 3.9592 Perceptual Loss: 0.0277
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0024 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0285 Adverserial Loss: 0.7010 Perceptual Loss: 0.0292
# 185 time: 3:15:53.467405
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0006 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0303 Adverserial Loss: 4.3023 Perceptual Loss: 0.0346
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0006 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0459 Adverserial Loss: 0.7063 Perceptual Loss: 0.0466
# 186 time: 3:16:53.526363
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0013 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0347 Adverserial Loss: 2.7272 Perceptual Loss: 0.0374
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0013 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0279 Adverserial Loss: 0.6988 Perceptual Loss: 0.0286
# 187 time: 3:17:51.861607
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0007 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0251 Adverserial Loss: 4.5896 Perceptual Loss: 0.0297
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0007 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0298 Adverserial Loss: 0.7043 Perceptual Loss: 0.0305
# 188 time: 3:18:53.496178
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0004 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0263 Adverserial Loss: 4.1763 Perceptual Loss: 0.0305
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0004 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0222 Adverserial Loss: 0.6998 Perceptual Loss: 0.0229
# 189 time: 3:19:54.413003
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0004 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0354 Adverserial Loss: 3.4657 Perceptual Loss: 0.0389
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0004 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0333 Adverserial Loss: 0.7016 Perceptual Loss: 0.0340
# 190 time: 3:20:53.370118
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0003 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0268 Adverserial Loss: 4.1545 Perceptual Loss: 0.0310
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0003 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0296 Adverserial Loss: 0.7052 Perceptual Loss: 0.0303
# 191 time: 3:21:53.662607
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0003 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 0.0317 Adverserial Loss: 4.0750 Perceptual Loss: 0.0358
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0003 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 0.0287 Adverserial Loss: 0.6987 Perceptual Loss: 0.0294
# 192 time: 3:22:54.027460
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0109 Training Accuracy: 0.9975
# Generator (Combined) => Training Content Loss: 0.0316 Adverserial Loss: 4.5040 Perceptual Loss: 0.0361
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0109 Testing Accuracy: 0.9975
# Generator (Combined) => Testing Content Loss: 0.0283 Adverserial Loss: 0.7234 Perceptual Loss: 0.0291
# 193 time: 3:23:54.183428
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.6156 Training Accuracy: 0.3215
# Generator (Combined) => Training Content Loss: 0.0204 Adverserial Loss: 0.0433 Perceptual Loss: 0.0205
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.6156 Testing Accuracy: 0.3215
# Generator (Combined) => Testing Content Loss: 0.0301 Adverserial Loss: 0.7636 Perceptual Loss: 0.0309
# 194 time: 3:24:53.381341
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4831 Training Accuracy: 0.4996
# Generator (Combined) => Training Content Loss: 0.0281 Adverserial Loss: 0.3665 Perceptual Loss: 0.0285
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4831 Testing Accuracy: 0.4996
# Generator (Combined) => Testing Content Loss: 0.0257 Adverserial Loss: 0.9670 Perceptual Loss: 0.0267
# 195 time: 3:25:53.240629
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4830 Training Accuracy: 0.4773
# Generator (Combined) => Training Content Loss: 0.0311 Adverserial Loss: 0.5129 Perceptual Loss: 0.0316
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4830 Testing Accuracy: 0.4773
# Generator (Combined) => Testing Content Loss: 0.0287 Adverserial Loss: 0.3583 Perceptual Loss: 0.0290
# 196 time: 3:26:53.163027
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.5174 Training Accuracy: 0.4600
# Generator (Combined) => Training Content Loss: 0.0299 Adverserial Loss: 0.1469 Perceptual Loss: 0.0301
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.5174 Testing Accuracy: 0.4600
# Generator (Combined) => Testing Content Loss: 0.0233 Adverserial Loss: 0.2051 Perceptual Loss: 0.0235
# 197 time: 3:27:51.575357
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4726 Training Accuracy: 0.4904
# Generator (Combined) => Training Content Loss: 0.0301 Adverserial Loss: 0.2464 Perceptual Loss: 0.0304
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4726 Testing Accuracy: 0.4904
# Generator (Combined) => Testing Content Loss: 0.0265 Adverserial Loss: 0.2178 Perceptual Loss: 0.0267
# 198 time: 3:28:54.338434
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4550 Training Accuracy: 0.4822
# Generator (Combined) => Training Content Loss: 0.0228 Adverserial Loss: 0.4674 Perceptual Loss: 0.0232
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4550 Testing Accuracy: 0.4822
# Generator (Combined) => Testing Content Loss: 0.0252 Adverserial Loss: 0.1404 Perceptual Loss: 0.0254
# 199 time: 3:29:56.049526
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4741 Training Accuracy: 0.4176
# Generator (Combined) => Training Content Loss: 0.0328 Adverserial Loss: 0.5372 Perceptual Loss: 0.0333
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4741 Testing Accuracy: 0.4176
# Generator (Combined) => Testing Content Loss: 0.0221 Adverserial Loss: 0.1778 Perceptual Loss: 0.0223
# 200 time: 3:30:57.019229
# PSNR: 21.5489 SSIM: 0.1289
# PSNR: 18.8778 SSIM: 0.1035
