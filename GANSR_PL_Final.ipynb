# %%
from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/MIE1516 Project/'
# Out:
# Mounted at /content/gdrive

# %%
import os
import cv2
import h5py
import numpy
import math
import skimage
from math import log10, sqrt 
from skimage.metrics import structural_similarity, peak_signal_noise_ratio

# %%
DATA_PATH = root_path + "/DIV2K_train_HR"
LR_DATA_PATH = root_path + "/DIV2K_train_LR_bicubic_X2/"
TEST_PATH = root_path + "/DIV2K_valid_HR/"

# %%
import scipy
from skimage import transform, io
import imageio
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
#Link: https://github.com/eriklindernoren/Keras-GAN
class DataLoader():
    def __init__(self, dataset_name, img_res=(128, 128)):
        self.dataset_name = dataset_name
        self.img_res = img_res

    def load_data(self, batch_size=1, is_testing=False):
        data_type = "train" if not is_testing else "test"
        
        path = glob('%s/*' % (self.dataset_name))

        batch_images = np.random.choice(path, size=batch_size)

        imgs_hr = []
        imgs_lr = []
        for img_path in batch_images:
            img = self.imread(img_path)

            h, w = self.img_res
            low_h, low_w = int(h / 4), int(w / 4)

            img_hr = transform.resize(img, self.img_res)
            img_lr = transform.resize(img, (low_h, low_w))

            # If training => do random flip
            if not is_testing and np.random.random() < 0.5:
                img_hr = np.fliplr(img_hr)
                img_lr = np.fliplr(img_lr)

            imgs_hr.append(img_hr)
            imgs_lr.append(img_lr)

        imgs_hr = np.array(imgs_hr) / 127.5 - 1.
        imgs_lr = np.array(imgs_lr) / 127.5 - 1.
        print(imgs_hr.shape)
        print(imgs_lr.shape)
        return imgs_hr, imgs_lr


    def imread(self, path):
        return imageio.imread(path, pilmode='RGB').astype(np.float)

# %%
class ImageMetrics():
  def __init__(self):
    self.name = "Metric for Image"
  
  def print_metrics(self, reference, generated):
    self.reference = (reference)*255.0
    self.generated = (generated)*255.0
    assert self.reference.shape == self.generated.shape
    psnr_score, ssim_score = self.psnr(), self.ssim()
    print("PSNR: %.4f SSIM: %.4f" % (psnr_score, ssim_score))
    return psnr_score, ssim_score

  #Link: https://dsp.stackexchange.com/questions/38065/peak-signal-to-noise-ratio-psnr-in-python-for-an-image
  def psnr(self):
    mse = np.mean((self.reference-self.generated)**2)
    if(mse == 0):
      mse = 100
    MAX_PIXEL = 255.0
    psnr_score = 20*log10(MAX_PIXEL/sqrt(mse))
    return psnr_score

  #Link: https://scikit-image.org/docs/dev/api/skimage.metrics.html#skimage.metrics.structural_similarity
  def ssim(self):
    (ssim_score, difference) = structural_similarity(self.reference, self.generated, multichannel= True, gaussian_weights= True, full=True)
    return ssim_score

# %%
"""
Super-resolution of CelebA using Generative Adversarial Networks.

The dataset can be downloaded from: https://www.dropbox.com/sh/8oqt9vytwxb3s4r/AADIKlz8PR9zr6Y20qbkunrba/Img/img_align_celeba.zip?dl=0

Instrustion on running the script:
1. Download the dataset from the provided link
2. Save the folder 'img_align_celeba' to 'datasets/'
4. Run the sript using command 'python srgan.py'
"""
#Link: https://github.com/eriklindernoren/Keras-GAN
from __future__ import print_function, division
import scipy
# !pip install git+https://www.github.com/keras-team/keras-contrib.git

# %tensorflow_version 1.x


from keras.datasets import mnist
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate
from keras.layers import BatchNormalization, Activation, ZeroPadding2D, Add
from keras.layers.advanced_activations import PReLU, LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.applications import VGG19
from keras.models import Sequential, Model
from keras.optimizers import Adam

import tensorflow as tf
import datetime
import matplotlib.pyplot as plt
import sys
#from data_loader import DataLoader
import numpy as np
import os
from collections import defaultdict
try:
    import cPickle as pickle
except ImportError:
    import pickle

import keras.backend as K

class SRGAN():
    def __init__(self):
        # Input shape
        self.channels = 3
        self.lr_height = 64                 # Low resolution height
        self.lr_width = 64                  # Low resolution width
        self.lr_shape = (self.lr_height, self.lr_width, self.channels)
        self.hr_height = self.lr_height*4   # High resolution height
        self.hr_width = self.lr_width*4     # High resolution width
        self.hr_shape = (self.hr_height, self.hr_width, self.channels)

        # Number of residual blocks in the generator
        self.n_residual_blocks = 16

        optimizer = Adam(0.0002, 0.5)

        # We use a pre-trained VGG19 model to extract image features from the high resolution
        # and the generated high resolution images and minimize the mse between them
        self.vgg = self.build_vgg()
        self.vgg.trainable = False
        self.vgg.compile(loss='mse',
            optimizer=optimizer,
            metrics=['accuracy'])

        # Configure data loader
        self.save_path_name = root_path
        self.dataset_name = DATA_PATH
        self.test_dataset_name = TEST_PATH
        self.data_loader = DataLoader(dataset_name=self.dataset_name,
                                      img_res=(self.hr_height, self.hr_width))
        self.test_data_loader = DataLoader(dataset_name=self.test_dataset_name,
                                      img_res=(self.hr_height, self.hr_width))
        self.metrics = ImageMetrics()
        
        self.model_gen_path = self.save_path_name + "SRGAN_PL/checkpoints/model_gen_april11.h5"
        self.model_disc_path = self.save_path_name + "SRGAN_PL/checkpoints/model_disc_april11.h5"
        self.model_combined_path = self.save_path_name + "SRGAN_PL/checkpoints/model_combined_april11.h5"
        self.sample_images_path = self.save_path_name + "SRGAN_PL/sample_image_outputs"
        self.history_loss_accuracy_path = self.save_path_name + "SRGAN_PL/srgan-pl-history.pkl"

        # Calculate output shape of D (PatchGAN)
        patch = int(self.hr_height / 2**4)
        self.disc_patch = (patch, patch, 1)

        # Number of filters in the first layer of G and D
        self.gf = 64
        self.df = 64

        # Build and compile the discriminator
        self.discriminator = self.build_discriminator()
        self.discriminator.compile(loss='mse',
            optimizer=optimizer,
            metrics=['accuracy'])

        # Build the generator
        self.generator = self.build_generator()

        # High res. and low res. images
        img_hr = Input(shape=self.hr_shape)
        img_lr = Input(shape=self.lr_shape)

        # Generate high res. version from low res.
        fake_hr = self.generator(img_lr)

        # Extract image features of the generated img
        fake_features = self.vgg(fake_hr)

        # For the combined model we will only train the generator
        self.discriminator.trainable = False

        # Discriminator determines validity of generated high res. images
        validity = self.discriminator(fake_hr)

        self.combined = Model([img_lr, img_hr], [validity, fake_features])
        self.combined.compile(loss=['binary_crossentropy', 'mse'],
                              loss_weights=[1e-3, 1],
                              optimizer=optimizer)


    def build_vgg(self):
        """
        Builds a pre-trained VGG19 model that outputs image features extracted at the
        third block of the model
        """
        vgg = VGG19(weights="imagenet")
        # Set outputs to outputs of last conv. layer in block 3
        # See architecture at: https://github.com/keras-team/keras/blob/master/keras/applications/vgg19.py
        vgg.outputs = [vgg.layers[9].output]

        img = Input(shape=self.hr_shape)

        # Extract image features
        img_features = vgg(img)

        return Model(img, img_features)

    def build_generator(self):

        def residual_block(layer_input, filters):
            """Residual block described in paper"""
            d = Conv2D(filters, kernel_size=3, strides=1, padding='same')(layer_input)
            d = Activation('relu')(d)
            d = BatchNormalization(momentum=0.8)(d)
            d = Conv2D(filters, kernel_size=3, strides=1, padding='same')(d)
            d = BatchNormalization(momentum=0.8)(d)
            d = Add()([d, layer_input])
            return d

        def deconv2d(layer_input):
            """Layers used during upsampling"""
            u = UpSampling2D(size=2)(layer_input)
            u = Conv2D(256, kernel_size=3, strides=1, padding='same')(u)
            u = Activation('relu')(u)
            return u

        # Low resolution image input
        img_lr = Input(shape=self.lr_shape)

        # # Pre-residual block
        # c1 = Conv2D(64, kernel_size=9, strides=1, padding='same')(img_lr)
        # c1 = Activation('relu')(c1)

        # # Propogate through residual blocks
        # r = residual_block(c1, self.gf)
        # for _ in range(self.n_residual_blocks - 1):
        #     r = residual_block(r, self.gf)

        # # Post-residual block
        # c2 = Conv2D(64, kernel_size=3, strides=1, padding='same')(r)
        # c2 = BatchNormalization(momentum=0.8)(c2)
        # c2 = Add()([c2, c1])

        # # Upsampling
        # u1 = deconv2d(c2)
        # u2 = deconv2d(u1)

        # # Generate high resolution output
        # gen_hr = Conv2D(self.channels, kernel_size=9, strides=1, padding='same', activation='tanh')(u2)
        c1 = Conv2D(128, kernel_size=9, strides=1, padding='same')(img_lr)
        c1 = Activation('relu')(c1)
        c2 = Conv2D(64, kernel_size=3, strides=1, padding='same')(c1)
        c2 = Activation('relu')(c2)
        c3 = Conv2D(3, kernel_size=5, strides=1, padding='same')(c2)
        c3 = Activation('linear')(c3)
        u1 = UpSampling2D(size=4)(c3)
        gen_hr = u1
        
        #gen_hr = Reshape(self.hr_shape)

        model_gen = Model(img_lr, gen_hr)
        print(model_gen.summary())
        return model_gen

    def build_discriminator(self):

        def d_block(layer_input, filters, strides=1, bn=True):
            """Discriminator layer"""
            d = Conv2D(filters, kernel_size=3, strides=strides, padding='same')(layer_input)
            d = LeakyReLU(alpha=0.2)(d)
            if bn:
                d = BatchNormalization(momentum=0.8)(d)
            return d

        # Input img
        d0 = Input(shape=self.hr_shape)

        d1 = d_block(d0, self.df, bn=False)
        d2 = d_block(d1, self.df, strides=2)
        d3 = d_block(d2, self.df*2)
        d4 = d_block(d3, self.df*2, strides=2)
        d5 = d_block(d4, self.df*4)
        d6 = d_block(d5, self.df*4, strides=2)
        d7 = d_block(d6, self.df*8)
        d8 = d_block(d7, self.df*8, strides=2)

        d9 = Dense(self.df*16)(d8)
        d10 = LeakyReLU(alpha=0.2)(d9)
        validity = Dense(1, activation='sigmoid')(d10)

        model_disc = Model(d0, validity)
        print(model_disc.summary())
        return model_disc

    def train(self, epochs, batch_size=1, sample_interval=50):

        start_time = datetime.datetime.now()

        if(os.path.exists(self.model_gen_path)):
          print("I am here")
          self.generator.load_weights(self.model_gen_path)

        if(os.path.exists(self.model_disc_path)):
          print("I am here")
          self.discriminator.load_weights(self.model_disc_path)
        
        if(os.path.exists(self.model_combined_path)):
          print("I am here")
          self.combined.load_weights(self.model_combined_path)

        train_dict = defaultdict(list)
        test_dict = defaultdict(list)
        sample_imgs_hr, sample_imgs_lr = self.test_data_loader.load_data(batch_size=2, is_testing=True)
        for epoch in range(epochs):

            # ----------------------
            #  Train Discriminator
            # ----------------------

            # Sample images and their conditioning counterparts
            imgs_hr, imgs_lr = self.data_loader.load_data(batch_size)
            # # For the combined model we will only train the generator
            # self.discriminator.trainable = True
            # From low res. image generate high res. version
            fake_hr = self.generator.predict(imgs_lr)

            valid = np.ones((batch_size,) + self.disc_patch)
            fake = np.zeros((batch_size,) + self.disc_patch)

            # Train the discriminators (original images = real / generated = Fake)
            d_loss_real = self.discriminator.train_on_batch(imgs_hr, valid)
            d_loss_fake = self.discriminator.train_on_batch(fake_hr, fake)
            d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

            # ------------------
            #  Train Generator
            # ------------------

            # Sample images and their conditioning counterparts
            imgs_hr, imgs_lr = self.data_loader.load_data(batch_size)
            # For the combined model we will only train the generator
            self.discriminator.trainable = False
            # The generators want the discriminators to label the generated images as real
            valid = np.ones((batch_size,) + self.disc_patch)

            # Extract ground truth image features using pre-trained VGG19 model
            image_features = self.vgg.predict(imgs_hr)

            # Train the generators
            g_loss = self.combined.train_on_batch([imgs_lr, imgs_hr], [valid, image_features])

            print("Training Losses")
            print("Discriminator Real + Fake => Training Loss: %.4f Training Accuracy: %.4f" %(d_loss[0], d_loss[1]))
            train_dict["discriminator"].append(d_loss)

            print("Generator (Combined) => Training Content Loss: %.4f Adverserial Loss: %.4f Perceptual Loss: %.4f" %(g_loss[2], g_loss[1], g_loss[0]))
            train_dict["generator"].append(g_loss)

            # ----------------------
            #  Test Discriminator
            # ----------------------

            # Sample images and their conditioning counterparts
            imgs_hr, imgs_lr = self.test_data_loader.load_data(batch_size,is_testing=True)
            # # For the combined model we will only train the generator
            # self.discriminator.trainable = True
            # From low res. image generate high res. version
            fake_hr = self.generator.predict(imgs_lr)

            valid = np.ones((batch_size,) + self.disc_patch)
            fake = np.zeros((batch_size,) + self.disc_patch)

            # Train the discriminators (original images = real / generated = Fake)
            test_d_loss_real = self.discriminator.test_on_batch(imgs_hr, valid)
            test_d_loss_fake = self.discriminator.test_on_batch(fake_hr, fake)
            test_d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

            # ------------------
            #  Test Generator
            # ------------------

            # Sample images and their conditioning counterparts
            imgs_hr, imgs_lr = self.test_data_loader.load_data(batch_size, is_testing=True)

            # The generators want the discriminators to label the generated images as real
            valid = np.ones((batch_size,) + self.disc_patch)

            # Extract ground truth image features using pre-trained VGG19 model
            image_features = self.vgg.predict(imgs_hr)

            # Train the generators
            test_g_loss = self.combined.test_on_batch([imgs_lr, imgs_hr], [valid, image_features])

            print("Testing Losses")
            print("Discriminator Real + Fake => Testing Loss: %.4f Testing Accuracy: %.4f" %(test_d_loss[0], test_d_loss[1]))
            test_dict["discriminator"].append(test_d_loss)

            print("Generator (Combined) => Testing Content Loss: %.4f Adverserial Loss: %.4f Perceptual Loss: %.4f" %(test_g_loss[2], test_g_loss[1], test_g_loss[0]))
            test_dict["generator"].append(test_g_loss)

            elapsed_time = datetime.datetime.now() - start_time
            # Plot the progress
            print ("%d time: %s" % (epoch, elapsed_time))

            self.generator.save_weights(self.model_gen_path)
            self.discriminator.save_weights(self.model_disc_path)
            self.combined.save_weights(self.model_combined_path)
            # If at save interval => save generated image samples
            if epoch % sample_interval == 0:
                self.sample_images(epoch,sample_imgs_hr, sample_imgs_lr )
        
        with open(self.history_loss_accuracy_path, 'wb') as f:
          pickle.dump({'train': train_dict, 'test': test_dict}, f)

    def sample_images(self, epoch, sample_imgs_hr=None, sample_imgs_lr=None):
        #os.makedirs('images/%s' % self.dataset_name, exist_ok=True)
        r, c = 2, 3

        if(sample_imgs_hr is None or sample_imgs_lr is None):
          imgs_hr, imgs_lr = self.test_data_loader.load_data(batch_size=2, is_testing=True)
        else:
          imgs_hr, imgs_lr = sample_imgs_hr,sample_imgs_lr

        fake_hr = self.generator.predict(imgs_lr)

        # Rescale images 0 - 1
        imgs_lr = 0.5 * imgs_lr + 0.5
        fake_hr = 0.5 * fake_hr + 0.5
        imgs_hr = 0.5 * imgs_hr + 0.5

        # Save generated images and the high resolution originals
        titles = ['LR Original','Generated', 'Original']
        fig, axs = plt.subplots(r, c)
        cnt = 0
        for row in range(r):
            psnr_score, ssim_score = self.metrics.print_metrics(reference=imgs_hr[row][2], generated=fake_hr[row][1])
            for col, image in enumerate([imgs_lr, fake_hr, imgs_hr]):
                if(row == 0):
                  if(titles[col] == 'Generated'):
                    col_title = "Generated \n PSNR: %.4f SSIM: %.4f" % (psnr_score, ssim_score)
                  else:
                    col_title = titles[col]+ "\n"
                else:
                  if(titles[col] == 'Generated'):
                    col_title = "PSNR: %.4f SSIM: %.4f" % (psnr_score, ssim_score)
                  else:
                    col_title = "\n"
                axs[row, col].imshow(image[row])
                axs[row, col].set_title(col_title)
                axs[row, col].axis('off')
            cnt += 1
        fig.savefig("%s/%d.png" % (self.sample_images_path, epoch))
        plt.close()

        # Save low resolution images for comparison
        if((epoch == 0 and (sample_imgs_hr is not None or sample_imgs_lr is not None)) or (sample_imgs_hr is None or sample_imgs_lr is None)):
          for i in range(r):
              fig = plt.figure()
              plt.imshow(imgs_lr[i])
              fig.savefig('%s/%d_lowres%d.png' % (self.sample_images_path, epoch, i))
              plt.close()

if __name__ == '__main__':
    tf.reset_default_graph()
    try:
        del gan
    except:
        pass
    K.clear_session()

    
    graph = tf.get_default_graph()

    with graph.as_default():
      gan = SRGAN()
      gan.train(epochs=201, batch_size=10, sample_interval=50)
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-eiou9kqz
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-eiou9kqz
# Requirement already satisfied (use --upgrade to upgrade): keras-contrib==2.0.8 from git+https://www.github.com/keras-team/keras-contrib.git in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.3.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.12.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.18.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.10.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101064 sha256=8fd371f10752b40c39c24e6c46e3dd4479d2118423357a12f12c0b535e14f4bf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-o8bka907/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 64)      1792
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128, 128, 64)      0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 128)     73856
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 128, 128, 128)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 128, 128)     512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 128)       147584
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64, 64, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 256)       295168
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64, 64, 256)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 64, 256)       1024
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 512)       1180160
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 32, 32, 512)       0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 512)       2048
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 512)       2359808
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 16, 16, 512)       0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 512)       2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 16, 16, 1024)      525312
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 16, 16, 1024)      0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16, 16, 1)         1025
# =================================================================
# Total params: 5,219,137
# Trainable params: 5,215,425
# Non-trainable params: 3,712
# _________________________________________________________________
# None
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 64, 64, 128)       31232
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 64, 64, 64)        73792
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 64, 64, 3)         4803
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 64, 3)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 256, 256, 3)       0
# =================================================================
# Total params: 109,827
# Trainable params: 109,827
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# (2, 256, 256, 3)
# (2, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3469 Training Accuracy: 0.4828
# Generator (Combined) => Training Content Loss: 70.3232 Adverserial Loss: 0.7717 Perceptual Loss: 70.3240
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3469 Testing Accuracy: 0.4828
# Generator (Combined) => Testing Content Loss: 65.8685 Adverserial Loss: 0.6892 Perceptual Loss: 65.8691
# 0 time: 0:01:24.308012
# /usr/local/lib/python3.6/dist-packages/skimage/metrics/_structural_similarity.py:108: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   im2[..., ch], **args)
# PSNR: 9.7081 SSIM: -0.0094
# PSNR: 14.7075 SSIM: -0.0037
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2560 Training Accuracy: 0.6379
# Generator (Combined) => Training Content Loss: 64.1250 Adverserial Loss: 1.1700 Perceptual Loss: 64.1262
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2560 Testing Accuracy: 0.6379
# Generator (Combined) => Testing Content Loss: 52.4936 Adverserial Loss: 0.6869 Perceptual Loss: 52.4943
# 1 time: 0:02:43.211186
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3412 Training Accuracy: 0.4750
# Generator (Combined) => Training Content Loss: 57.9817 Adverserial Loss: 1.3376 Perceptual Loss: 57.9831
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3412 Testing Accuracy: 0.4750
# Generator (Combined) => Testing Content Loss: 62.2995 Adverserial Loss: 0.6915 Perceptual Loss: 62.3002
# 2 time: 0:04:02.841387
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2714 Training Accuracy: 0.5928
# Generator (Combined) => Training Content Loss: 56.2599 Adverserial Loss: 1.8018 Perceptual Loss: 56.2617
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2714 Testing Accuracy: 0.5928
# Generator (Combined) => Testing Content Loss: 44.2674 Adverserial Loss: 0.6938 Perceptual Loss: 44.2681
# 3 time: 0:05:19.868519
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1714 Training Accuracy: 0.7643
# Generator (Combined) => Training Content Loss: 52.9607 Adverserial Loss: 2.4414 Perceptual Loss: 52.9632
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1714 Testing Accuracy: 0.7643
# Generator (Combined) => Testing Content Loss: 48.1591 Adverserial Loss: 0.6955 Perceptual Loss: 48.1598
# 4 time: 0:06:39.486322
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1105 Training Accuracy: 0.8531
# Generator (Combined) => Training Content Loss: 53.2222 Adverserial Loss: 2.3294 Perceptual Loss: 53.2246
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1105 Testing Accuracy: 0.8531
# Generator (Combined) => Testing Content Loss: 53.8340 Adverserial Loss: 0.6939 Perceptual Loss: 53.8347
# 5 time: 0:07:55.620074
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2145 Training Accuracy: 0.6695
# Generator (Combined) => Training Content Loss: 55.2178 Adverserial Loss: 2.2850 Perceptual Loss: 55.2201
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2145 Testing Accuracy: 0.6695
# Generator (Combined) => Testing Content Loss: 51.4058 Adverserial Loss: 0.6921 Perceptual Loss: 51.4065
# 6 time: 0:09:12.002011
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0328 Training Accuracy: 0.9889
# Generator (Combined) => Training Content Loss: 50.8179 Adverserial Loss: 2.7417 Perceptual Loss: 50.8206
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0328 Testing Accuracy: 0.9889
# Generator (Combined) => Testing Content Loss: 49.4946 Adverserial Loss: 0.6940 Perceptual Loss: 49.4953
# 7 time: 0:10:29.089575
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0277 Training Accuracy: 0.9922
# Generator (Combined) => Training Content Loss: 57.8046 Adverserial Loss: 2.7377 Perceptual Loss: 57.8074
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0277 Testing Accuracy: 0.9922
# Generator (Combined) => Testing Content Loss: 46.2664 Adverserial Loss: 0.6934 Perceptual Loss: 46.2671
# 8 time: 0:11:48.015148
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0157 Training Accuracy: 0.9951
# Generator (Combined) => Training Content Loss: 41.1215 Adverserial Loss: 3.0401 Perceptual Loss: 41.1245
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0157 Testing Accuracy: 0.9951
# Generator (Combined) => Testing Content Loss: 45.0711 Adverserial Loss: 0.6932 Perceptual Loss: 45.0718
# 9 time: 0:13:04.624305
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0247 Training Accuracy: 0.9867
# Generator (Combined) => Training Content Loss: 47.1444 Adverserial Loss: 3.2326 Perceptual Loss: 47.1476
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0247 Testing Accuracy: 0.9867
# Generator (Combined) => Testing Content Loss: 46.3609 Adverserial Loss: 0.6940 Perceptual Loss: 46.3616
# 10 time: 0:14:17.510730
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3151 Training Accuracy: 0.5193
# Generator (Combined) => Training Content Loss: 38.2718 Adverserial Loss: 3.0924 Perceptual Loss: 38.2749
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3151 Testing Accuracy: 0.5193
# Generator (Combined) => Testing Content Loss: 40.2281 Adverserial Loss: 0.7007 Perceptual Loss: 40.2288
# 11 time: 0:15:31.077565
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3385 Training Accuracy: 0.4986
# Generator (Combined) => Training Content Loss: 44.3505 Adverserial Loss: 2.5697 Perceptual Loss: 44.3531
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3385 Testing Accuracy: 0.4986
# Generator (Combined) => Testing Content Loss: 51.6945 Adverserial Loss: 0.6930 Perceptual Loss: 51.6952
# 12 time: 0:16:45.641909
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3469 Training Accuracy: 0.5420
# Generator (Combined) => Training Content Loss: 41.3194 Adverserial Loss: 2.5750 Perceptual Loss: 41.3219
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3469 Testing Accuracy: 0.5420
# Generator (Combined) => Testing Content Loss: 43.7022 Adverserial Loss: 0.6942 Perceptual Loss: 43.7029
# 13 time: 0:18:05.934882
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1165 Training Accuracy: 0.8635
# Generator (Combined) => Training Content Loss: 36.4392 Adverserial Loss: 2.9018 Perceptual Loss: 36.4421
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1165 Testing Accuracy: 0.8635
# Generator (Combined) => Testing Content Loss: 43.1832 Adverserial Loss: 0.7000 Perceptual Loss: 43.1839
# 14 time: 0:19:22.118305
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2783 Training Accuracy: 0.6387
# Generator (Combined) => Training Content Loss: 41.4409 Adverserial Loss: 2.8405 Perceptual Loss: 41.4437
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2783 Testing Accuracy: 0.6387
# Generator (Combined) => Testing Content Loss: 36.3556 Adverserial Loss: 0.7050 Perceptual Loss: 36.3563
# 15 time: 0:20:38.591642
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1393 Training Accuracy: 0.8039
# Generator (Combined) => Training Content Loss: 41.5388 Adverserial Loss: 2.7756 Perceptual Loss: 41.5415
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1393 Testing Accuracy: 0.8039
# Generator (Combined) => Testing Content Loss: 38.1567 Adverserial Loss: 0.6967 Perceptual Loss: 38.1574
# 16 time: 0:21:58.874567
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0638 Training Accuracy: 0.9467
# Generator (Combined) => Training Content Loss: 37.5989 Adverserial Loss: 3.4292 Perceptual Loss: 37.6023
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0638 Testing Accuracy: 0.9467
# Generator (Combined) => Testing Content Loss: 40.0604 Adverserial Loss: 0.6984 Perceptual Loss: 40.0611
# 17 time: 0:23:13.230026
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0262 Training Accuracy: 0.9951
# Generator (Combined) => Training Content Loss: 36.8078 Adverserial Loss: 3.5568 Perceptual Loss: 36.8113
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0262 Testing Accuracy: 0.9951
# Generator (Combined) => Testing Content Loss: 39.6923 Adverserial Loss: 0.7004 Perceptual Loss: 39.6931
# 18 time: 0:24:27.101414
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0792 Training Accuracy: 0.9014
# Generator (Combined) => Training Content Loss: 43.6019 Adverserial Loss: 3.8291 Perceptual Loss: 43.6057
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0792 Testing Accuracy: 0.9014
# Generator (Combined) => Testing Content Loss: 34.4657 Adverserial Loss: 0.7095 Perceptual Loss: 34.4664
# 19 time: 0:25:43.462242
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.5353 Training Accuracy: 0.2764
# Generator (Combined) => Training Content Loss: 35.0836 Adverserial Loss: 1.5334 Perceptual Loss: 35.0851
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.5353 Testing Accuracy: 0.2764
# Generator (Combined) => Testing Content Loss: 32.3539 Adverserial Loss: 0.6971 Perceptual Loss: 32.3546
# 20 time: 0:27:00.231011
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1721 Training Accuracy: 0.7330
# Generator (Combined) => Training Content Loss: 35.4335 Adverserial Loss: 3.5654 Perceptual Loss: 35.4370
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1721 Testing Accuracy: 0.7330
# Generator (Combined) => Testing Content Loss: 36.4129 Adverserial Loss: 0.7376 Perceptual Loss: 36.4136
# 21 time: 0:28:18.829559
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3199 Training Accuracy: 0.5373
# Generator (Combined) => Training Content Loss: 33.4524 Adverserial Loss: 3.4048 Perceptual Loss: 33.4558
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3199 Testing Accuracy: 0.5373
# Generator (Combined) => Testing Content Loss: 36.7612 Adverserial Loss: 0.7796 Perceptual Loss: 36.7620
# 22 time: 0:29:34.315493
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2067 Training Accuracy: 0.7312
# Generator (Combined) => Training Content Loss: 33.8572 Adverserial Loss: 3.4631 Perceptual Loss: 33.8607
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2067 Testing Accuracy: 0.7312
# Generator (Combined) => Testing Content Loss: 37.4932 Adverserial Loss: 0.7201 Perceptual Loss: 37.4940
# 23 time: 0:30:47.699785
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1782 Training Accuracy: 0.7691
# Generator (Combined) => Training Content Loss: 36.6291 Adverserial Loss: 3.1631 Perceptual Loss: 36.6322
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1782 Testing Accuracy: 0.7691
# Generator (Combined) => Testing Content Loss: 31.8896 Adverserial Loss: 0.7135 Perceptual Loss: 31.8903
# 24 time: 0:31:59.971529
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0298 Training Accuracy: 0.9736
# Generator (Combined) => Training Content Loss: 29.9454 Adverserial Loss: 2.8657 Perceptual Loss: 29.9483
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0298 Testing Accuracy: 0.9736
# Generator (Combined) => Testing Content Loss: 34.8337 Adverserial Loss: 0.7042 Perceptual Loss: 34.8344
# 25 time: 0:33:13.033689
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0237 Training Accuracy: 0.9824
# Generator (Combined) => Training Content Loss: 32.2319 Adverserial Loss: 3.6360 Perceptual Loss: 32.2356
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0237 Testing Accuracy: 0.9824
# Generator (Combined) => Testing Content Loss: 37.8549 Adverserial Loss: 0.7264 Perceptual Loss: 37.8556
# 26 time: 0:34:26.542416
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0216 Training Accuracy: 0.9889
# Generator (Combined) => Training Content Loss: 31.7043 Adverserial Loss: 4.0389 Perceptual Loss: 31.7084
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0216 Testing Accuracy: 0.9889
# Generator (Combined) => Testing Content Loss: 35.0709 Adverserial Loss: 0.7238 Perceptual Loss: 35.0716
# 27 time: 0:35:42.040040
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0128 Training Accuracy: 0.9969
# Generator (Combined) => Training Content Loss: 31.5030 Adverserial Loss: 3.3560 Perceptual Loss: 31.5063
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0128 Testing Accuracy: 0.9969
# Generator (Combined) => Testing Content Loss: 31.6912 Adverserial Loss: 0.7263 Perceptual Loss: 31.6919
# 28 time: 0:36:58.386699
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0091 Training Accuracy: 0.9914
# Generator (Combined) => Training Content Loss: 36.8342 Adverserial Loss: 2.5098 Perceptual Loss: 36.8368
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0091 Testing Accuracy: 0.9914
# Generator (Combined) => Testing Content Loss: 34.8459 Adverserial Loss: 0.7220 Perceptual Loss: 34.8467
# 29 time: 0:38:12.851743
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0147 Training Accuracy: 0.9885
# Generator (Combined) => Training Content Loss: 35.1552 Adverserial Loss: 3.8319 Perceptual Loss: 35.1590
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0147 Testing Accuracy: 0.9885
# Generator (Combined) => Testing Content Loss: 30.7951 Adverserial Loss: 0.7249 Perceptual Loss: 30.7958
# 30 time: 0:39:27.003656
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0019 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 31.1254 Adverserial Loss: 4.1828 Perceptual Loss: 31.1296
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0019 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 40.3809 Adverserial Loss: 0.7180 Perceptual Loss: 40.3816
# 31 time: 0:40:40.438292
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0144 Training Accuracy: 0.9891
# Generator (Combined) => Training Content Loss: 29.9663 Adverserial Loss: 3.5577 Perceptual Loss: 29.9698
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0144 Testing Accuracy: 0.9891
# Generator (Combined) => Testing Content Loss: 33.4028 Adverserial Loss: 0.7218 Perceptual Loss: 33.4035
# 32 time: 0:41:48.902412
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0016 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 32.7686 Adverserial Loss: 4.1522 Perceptual Loss: 32.7728
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0016 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 35.7183 Adverserial Loss: 0.7123 Perceptual Loss: 35.7190
# 33 time: 0:43:03.144659
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.5708 Training Accuracy: 0.3070
# Generator (Combined) => Training Content Loss: 40.7188 Adverserial Loss: 0.7924 Perceptual Loss: 40.7196
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.5708 Testing Accuracy: 0.3070
# Generator (Combined) => Testing Content Loss: 32.2849 Adverserial Loss: 0.7024 Perceptual Loss: 32.2856
# 34 time: 0:44:13.911036
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4629 Training Accuracy: 0.4404
# Generator (Combined) => Training Content Loss: 28.0408 Adverserial Loss: 0.9515 Perceptual Loss: 28.0417
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4629 Testing Accuracy: 0.4404
# Generator (Combined) => Testing Content Loss: 39.5538 Adverserial Loss: 0.6946 Perceptual Loss: 39.5545
# 35 time: 0:45:27.954807
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4400 Training Accuracy: 0.4563
# Generator (Combined) => Training Content Loss: 35.4448 Adverserial Loss: 0.7375 Perceptual Loss: 35.4455
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4400 Testing Accuracy: 0.4563
# Generator (Combined) => Testing Content Loss: 27.4861 Adverserial Loss: 0.6957 Perceptual Loss: 27.4868
# 36 time: 0:46:42.463562
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4021 Training Accuracy: 0.4924
# Generator (Combined) => Training Content Loss: 27.9200 Adverserial Loss: 1.2313 Perceptual Loss: 27.9213
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4021 Testing Accuracy: 0.4924
# Generator (Combined) => Testing Content Loss: 33.8758 Adverserial Loss: 0.6969 Perceptual Loss: 33.8765
# 37 time: 0:47:56.050457
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3966 Training Accuracy: 0.5158
# Generator (Combined) => Training Content Loss: 32.5312 Adverserial Loss: 1.2190 Perceptual Loss: 32.5324
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3966 Testing Accuracy: 0.5158
# Generator (Combined) => Testing Content Loss: 30.8885 Adverserial Loss: 0.6923 Perceptual Loss: 30.8892
# 38 time: 0:49:04.521512
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3993 Training Accuracy: 0.5057
# Generator (Combined) => Training Content Loss: 24.1178 Adverserial Loss: 0.7576 Perceptual Loss: 24.1185
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3993 Testing Accuracy: 0.5057
# Generator (Combined) => Testing Content Loss: 38.0014 Adverserial Loss: 0.7028 Perceptual Loss: 38.0021
# 39 time: 0:50:17.829823
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3612 Training Accuracy: 0.5010
# Generator (Combined) => Training Content Loss: 25.9658 Adverserial Loss: 1.0113 Perceptual Loss: 25.9668
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3612 Testing Accuracy: 0.5010
# Generator (Combined) => Testing Content Loss: 32.7908 Adverserial Loss: 0.6834 Perceptual Loss: 32.7915
# 40 time: 0:51:29.313641
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3391 Training Accuracy: 0.5080
# Generator (Combined) => Training Content Loss: 29.7920 Adverserial Loss: 1.4821 Perceptual Loss: 29.7935
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3391 Testing Accuracy: 0.5080
# Generator (Combined) => Testing Content Loss: 29.6108 Adverserial Loss: 0.6899 Perceptual Loss: 29.6115
# 41 time: 0:52:46.534575
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2574 Training Accuracy: 0.5748
# Generator (Combined) => Training Content Loss: 31.1306 Adverserial Loss: 2.1860 Perceptual Loss: 31.1328
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2574 Testing Accuracy: 0.5748
# Generator (Combined) => Testing Content Loss: 40.8356 Adverserial Loss: 0.7105 Perceptual Loss: 40.8363
# 42 time: 0:54:03.324482
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2665 Training Accuracy: 0.5768
# Generator (Combined) => Training Content Loss: 23.1609 Adverserial Loss: 2.3019 Perceptual Loss: 23.1632
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2665 Testing Accuracy: 0.5768
# Generator (Combined) => Testing Content Loss: 33.9418 Adverserial Loss: 0.7253 Perceptual Loss: 33.9426
# 43 time: 0:55:13.716076
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4630 Training Accuracy: 0.3133
# Generator (Combined) => Training Content Loss: 27.1868 Adverserial Loss: 1.9887 Perceptual Loss: 27.1888
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4630 Testing Accuracy: 0.3133
# Generator (Combined) => Testing Content Loss: 37.0726 Adverserial Loss: 0.7180 Perceptual Loss: 37.0733
# 44 time: 0:56:29.456623
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2703 Training Accuracy: 0.5646
# Generator (Combined) => Training Content Loss: 28.8580 Adverserial Loss: 2.1557 Perceptual Loss: 28.8601
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2703 Testing Accuracy: 0.5646
# Generator (Combined) => Testing Content Loss: 26.2312 Adverserial Loss: 0.7191 Perceptual Loss: 26.2319
# 45 time: 0:57:39.651721
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0671 Training Accuracy: 0.9574
# Generator (Combined) => Training Content Loss: 25.4005 Adverserial Loss: 2.6919 Perceptual Loss: 25.4032
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0671 Testing Accuracy: 0.9574
# Generator (Combined) => Testing Content Loss: 48.6987 Adverserial Loss: 0.7409 Perceptual Loss: 48.6994
# 46 time: 0:58:51.412785
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0623 Training Accuracy: 0.9363
# Generator (Combined) => Training Content Loss: 28.5931 Adverserial Loss: 3.1414 Perceptual Loss: 28.5962
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0623 Testing Accuracy: 0.9363
# Generator (Combined) => Testing Content Loss: 27.5307 Adverserial Loss: 0.7062 Perceptual Loss: 27.5314
# 47 time: 1:00:02.739941
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.5473 Training Accuracy: 0.2049
# Generator (Combined) => Training Content Loss: 27.1286 Adverserial Loss: 0.3901 Perceptual Loss: 27.1290
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.5473 Testing Accuracy: 0.2049
# Generator (Combined) => Testing Content Loss: 23.8825 Adverserial Loss: 0.7467 Perceptual Loss: 23.8833
# 48 time: 1:01:11.777137
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2984 Training Accuracy: 0.6031
# Generator (Combined) => Training Content Loss: 26.2501 Adverserial Loss: 2.2259 Perceptual Loss: 26.2523
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2984 Testing Accuracy: 0.6031
# Generator (Combined) => Testing Content Loss: 25.3982 Adverserial Loss: 0.7377 Perceptual Loss: 25.3989
# 49 time: 1:02:17.737918
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3566 Training Accuracy: 0.5049
# Generator (Combined) => Training Content Loss: 34.4177 Adverserial Loss: 2.0311 Perceptual Loss: 34.4197
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3566 Testing Accuracy: 0.5049
# Generator (Combined) => Testing Content Loss: 25.0257 Adverserial Loss: 0.7357 Perceptual Loss: 25.0265
# 50 time: 1:03:25.704657
# PSNR: 13.1837 SSIM: 0.0717
# PSNR: 18.6233 SSIM: 0.0791
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2994 Training Accuracy: 0.5338
# Generator (Combined) => Training Content Loss: 33.4589 Adverserial Loss: 2.6735 Perceptual Loss: 33.4616
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2994 Testing Accuracy: 0.5338
# Generator (Combined) => Testing Content Loss: 19.5574 Adverserial Loss: 0.7576 Perceptual Loss: 19.5582
# 51 time: 1:04:42.247326
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1917 Training Accuracy: 0.7061
# Generator (Combined) => Training Content Loss: 28.3010 Adverserial Loss: 2.2899 Perceptual Loss: 28.3033
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1917 Testing Accuracy: 0.7061
# Generator (Combined) => Testing Content Loss: 38.9656 Adverserial Loss: 0.6533 Perceptual Loss: 38.9663
# 52 time: 1:05:53.270489
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0985 Training Accuracy: 0.8664
# Generator (Combined) => Training Content Loss: 29.2292 Adverserial Loss: 2.8544 Perceptual Loss: 29.2321
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0985 Testing Accuracy: 0.8664
# Generator (Combined) => Testing Content Loss: 25.8654 Adverserial Loss: 0.7035 Perceptual Loss: 25.8661
# 53 time: 1:07:07.074632
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0497 Training Accuracy: 0.9693
# Generator (Combined) => Training Content Loss: 23.6651 Adverserial Loss: 2.8494 Perceptual Loss: 23.6680
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0497 Testing Accuracy: 0.9693
# Generator (Combined) => Testing Content Loss: 33.8554 Adverserial Loss: 0.6565 Perceptual Loss: 33.8560
# 54 time: 1:08:17.128603
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0212 Training Accuracy: 0.9896
# Generator (Combined) => Training Content Loss: 30.9361 Adverserial Loss: 3.2929 Perceptual Loss: 30.9394
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0212 Testing Accuracy: 0.9896
# Generator (Combined) => Testing Content Loss: 23.3692 Adverserial Loss: 0.6352 Perceptual Loss: 23.3699
# 55 time: 1:09:28.246337
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1030 Training Accuracy: 0.8965
# Generator (Combined) => Training Content Loss: 26.0262 Adverserial Loss: 2.4530 Perceptual Loss: 26.0286
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1030 Testing Accuracy: 0.8965
# Generator (Combined) => Testing Content Loss: 25.8096 Adverserial Loss: 0.6245 Perceptual Loss: 25.8102
# 56 time: 1:10:43.837159
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.5621 Training Accuracy: 0.2709
# Generator (Combined) => Training Content Loss: 27.5302 Adverserial Loss: 3.1515 Perceptual Loss: 27.5333
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.5621 Testing Accuracy: 0.2709
# Generator (Combined) => Testing Content Loss: 35.2002 Adverserial Loss: 0.7951 Perceptual Loss: 35.2010
# 57 time: 1:11:57.635334
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4514 Training Accuracy: 0.3422
# Generator (Combined) => Training Content Loss: 25.2385 Adverserial Loss: 3.3578 Perceptual Loss: 25.2418
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4514 Testing Accuracy: 0.3422
# Generator (Combined) => Testing Content Loss: 20.0128 Adverserial Loss: 1.1093 Perceptual Loss: 20.0139
# 58 time: 1:13:11.709992
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4384 Training Accuracy: 0.3975
# Generator (Combined) => Training Content Loss: 27.1269 Adverserial Loss: 2.3134 Perceptual Loss: 27.1292
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4384 Testing Accuracy: 0.3975
# Generator (Combined) => Testing Content Loss: 23.2344 Adverserial Loss: 0.8863 Perceptual Loss: 23.2353
# 59 time: 1:14:24.143487
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4037 Training Accuracy: 0.4352
# Generator (Combined) => Training Content Loss: 24.8855 Adverserial Loss: 1.8335 Perceptual Loss: 24.8874
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4037 Testing Accuracy: 0.4352
# Generator (Combined) => Testing Content Loss: 33.9263 Adverserial Loss: 1.0705 Perceptual Loss: 33.9274
# 60 time: 1:15:32.831614
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3745 Training Accuracy: 0.4621
# Generator (Combined) => Training Content Loss: 25.5844 Adverserial Loss: 1.8529 Perceptual Loss: 25.5862
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3745 Testing Accuracy: 0.4621
# Generator (Combined) => Testing Content Loss: 20.9634 Adverserial Loss: 0.9705 Perceptual Loss: 20.9644
# 61 time: 1:16:44.106373
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3352 Training Accuracy: 0.5000
# Generator (Combined) => Training Content Loss: 23.5622 Adverserial Loss: 2.0116 Perceptual Loss: 23.5642
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3352 Testing Accuracy: 0.5000
# Generator (Combined) => Testing Content Loss: 26.1607 Adverserial Loss: 0.9131 Perceptual Loss: 26.1616
# 62 time: 1:17:52.868285
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3489 Training Accuracy: 0.5102
# Generator (Combined) => Training Content Loss: 27.3864 Adverserial Loss: 2.5773 Perceptual Loss: 27.3890
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3489 Testing Accuracy: 0.5102
# Generator (Combined) => Testing Content Loss: 40.6200 Adverserial Loss: 0.7936 Perceptual Loss: 40.6208
# 63 time: 1:19:03.201674
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3492 Training Accuracy: 0.4480
# Generator (Combined) => Training Content Loss: 24.2716 Adverserial Loss: 2.3098 Perceptual Loss: 24.2739
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.3492 Testing Accuracy: 0.4480
# Generator (Combined) => Testing Content Loss: 42.4132 Adverserial Loss: 1.0467 Perceptual Loss: 42.4143
# 64 time: 1:20:15.727117
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.1449 Training Accuracy: 0.8166
# Generator (Combined) => Training Content Loss: 32.5031 Adverserial Loss: 2.6796 Perceptual Loss: 32.5057
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.1449 Testing Accuracy: 0.8166
# Generator (Combined) => Testing Content Loss: 23.5863 Adverserial Loss: 1.1196 Perceptual Loss: 23.5874
# 65 time: 1:21:29.696766
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4946 Training Accuracy: 0.2998
# Generator (Combined) => Training Content Loss: 26.8202 Adverserial Loss: 1.6232 Perceptual Loss: 26.8218
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4946 Testing Accuracy: 0.2998
# Generator (Combined) => Testing Content Loss: 22.3062 Adverserial Loss: 0.7361 Perceptual Loss: 22.3069
# 66 time: 1:22:40.833177
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.4198 Training Accuracy: 0.3900
# Generator (Combined) => Training Content Loss: 23.7991 Adverserial Loss: 1.4391 Perceptual Loss: 23.8005
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.4198 Testing Accuracy: 0.3900
# Generator (Combined) => Testing Content Loss: 28.7241 Adverserial Loss: 0.6939 Perceptual Loss: 28.7248
# 67 time: 1:23:50.525845
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.2796 Training Accuracy: 0.5609
# Generator (Combined) => Training Content Loss: 25.6716 Adverserial Loss: 1.8074 Perceptual Loss: 25.6734
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.2796 Testing Accuracy: 0.5609
# Generator (Combined) => Testing Content Loss: 25.0214 Adverserial Loss: 0.7021 Perceptual Loss: 25.0221
# 68 time: 1:25:01.748627
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.3347 Training Accuracy: 0.4518
# Generator (Combined) => Training Content Loss: 22.0171 Adverserial Loss: 1.0103 Perceptual Loss: 22.0181
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# ...
# Generator (Combined) => Training Content Loss: 19.5573 Adverserial Loss: 3.5511 Perceptual Loss: 19.5609
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0027 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 27.8533 Adverserial Loss: 1.1127 Perceptual Loss: 27.8544
# 172 time: 3:30:30.768322
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0127 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 21.9446 Adverserial Loss: 3.3813 Perceptual Loss: 21.9480
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0127 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 29.2066 Adverserial Loss: 1.0433 Perceptual Loss: 29.2076
# 173 time: 3:31:40.262385
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0091 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 19.0693 Adverserial Loss: 3.2153 Perceptual Loss: 19.0725
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0091 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 20.8647 Adverserial Loss: 1.1159 Perceptual Loss: 20.8658
# 174 time: 3:32:49.983194
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0047 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 19.4465 Adverserial Loss: 3.2120 Perceptual Loss: 19.4497
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0047 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 17.0415 Adverserial Loss: 1.1431 Perceptual Loss: 17.0427
# 175 time: 3:34:03.387567
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0055 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 24.2537 Adverserial Loss: 3.7788 Perceptual Loss: 24.2575
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0055 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 24.0341 Adverserial Loss: 0.9907 Perceptual Loss: 24.0351
# 176 time: 3:35:12.946097
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0039 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 24.2788 Adverserial Loss: 3.5769 Perceptual Loss: 24.2824
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0039 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 20.6558 Adverserial Loss: 1.2099 Perceptual Loss: 20.6570
# 177 time: 3:36:25.854920
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0077 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 18.7731 Adverserial Loss: 3.5845 Perceptual Loss: 18.7767
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0077 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 20.2800 Adverserial Loss: 1.0823 Perceptual Loss: 20.2811
# 178 time: 3:37:39.385457
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0025 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 22.5011 Adverserial Loss: 3.6938 Perceptual Loss: 22.5048
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0025 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 24.2037 Adverserial Loss: 1.0634 Perceptual Loss: 24.2047
# 179 time: 3:38:47.066045
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0032 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 19.8282 Adverserial Loss: 3.2642 Perceptual Loss: 19.8315
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0032 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 29.4300 Adverserial Loss: 1.0857 Perceptual Loss: 29.4311
# 180 time: 3:39:56.780038
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0032 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 21.7664 Adverserial Loss: 3.5395 Perceptual Loss: 21.7700
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0032 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 26.5151 Adverserial Loss: 1.0271 Perceptual Loss: 26.5161
# 181 time: 3:41:03.635673
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0018 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 20.5267 Adverserial Loss: 3.3348 Perceptual Loss: 20.5300
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0018 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 21.7025 Adverserial Loss: 1.0159 Perceptual Loss: 21.7035
# 182 time: 3:42:12.928373
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0018 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 21.4122 Adverserial Loss: 3.7625 Perceptual Loss: 21.4160
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0018 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 29.0692 Adverserial Loss: 1.2585 Perceptual Loss: 29.0705
# 183 time: 3:43:19.607602
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0025 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 27.3831 Adverserial Loss: 3.4916 Perceptual Loss: 27.3866
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0025 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 21.7498 Adverserial Loss: 1.1095 Perceptual Loss: 21.7510
# 184 time: 3:44:28.797075
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0090 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 24.0615 Adverserial Loss: 2.9380 Perceptual Loss: 24.0644
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0090 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 23.6939 Adverserial Loss: 0.9319 Perceptual Loss: 23.6948
# 185 time: 3:45:39.127348
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0020 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 22.4848 Adverserial Loss: 3.4150 Perceptual Loss: 22.4882
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0020 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 21.1621 Adverserial Loss: 0.8688 Perceptual Loss: 21.1630
# 186 time: 3:46:47.134175
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0091 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 24.6523 Adverserial Loss: 3.1062 Perceptual Loss: 24.6554
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0091 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 21.0176 Adverserial Loss: 1.0106 Perceptual Loss: 21.0186
# 187 time: 3:47:59.300979
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0026 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 20.8214 Adverserial Loss: 3.2730 Perceptual Loss: 20.8246
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0026 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 19.7558 Adverserial Loss: 1.2141 Perceptual Loss: 19.7570
# 188 time: 3:49:07.479299
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0036 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 22.6349 Adverserial Loss: 3.7435 Perceptual Loss: 22.6386
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0036 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 17.1261 Adverserial Loss: 1.1467 Perceptual Loss: 17.1273
# 189 time: 3:50:18.146745
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0017 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 23.9278 Adverserial Loss: 3.6978 Perceptual Loss: 23.9315
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0017 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 24.3881 Adverserial Loss: 1.1758 Perceptual Loss: 24.3892
# 190 time: 3:51:23.847318
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0024 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 25.9464 Adverserial Loss: 3.6361 Perceptual Loss: 25.9500
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0024 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 22.4300 Adverserial Loss: 1.0919 Perceptual Loss: 22.4311
# 191 time: 3:52:32.479972
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0014 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 24.5796 Adverserial Loss: 4.4642 Perceptual Loss: 24.5841
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0014 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 22.8785 Adverserial Loss: 1.0230 Perceptual Loss: 22.8795
# 192 time: 3:53:43.306435
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0015 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 21.5426 Adverserial Loss: 3.8784 Perceptual Loss: 21.5465
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0015 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 19.7331 Adverserial Loss: 0.9586 Perceptual Loss: 19.7340
# 193 time: 3:54:54.318305
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0043 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 20.4470 Adverserial Loss: 3.4648 Perceptual Loss: 20.4504
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0043 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 20.5437 Adverserial Loss: 1.0510 Perceptual Loss: 20.5448
# 194 time: 3:56:02.623763
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0014 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 18.7663 Adverserial Loss: 3.6207 Perceptual Loss: 18.7699
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0014 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 22.0450 Adverserial Loss: 1.0238 Perceptual Loss: 22.0460
# 195 time: 3:57:15.029034
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0020 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 20.5077 Adverserial Loss: 3.7957 Perceptual Loss: 20.5115
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0020 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 26.1356 Adverserial Loss: 1.0869 Perceptual Loss: 26.1367
# 196 time: 3:58:23.897803
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0027 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 26.4523 Adverserial Loss: 2.9647 Perceptual Loss: 26.4553
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0027 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 19.4444 Adverserial Loss: 1.1495 Perceptual Loss: 19.4455
# 197 time: 3:59:31.600836
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0055 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 26.5978 Adverserial Loss: 3.1491 Perceptual Loss: 26.6009
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0055 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 23.7698 Adverserial Loss: 1.0582 Perceptual Loss: 23.7709
# 198 time: 4:00:44.029380
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0019 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 21.3148 Adverserial Loss: 4.3350 Perceptual Loss: 21.3191
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0019 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 25.5913 Adverserial Loss: 1.0532 Perceptual Loss: 25.5923
# 199 time: 4:01:53.921379
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Discriminator Real + Fake => Training Loss: 0.0018 Training Accuracy: 1.0000
# Generator (Combined) => Training Content Loss: 19.9225 Adverserial Loss: 3.9369 Perceptual Loss: 19.9264
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Discriminator Real + Fake => Testing Loss: 0.0018 Testing Accuracy: 1.0000
# Generator (Combined) => Testing Content Loss: 31.9291 Adverserial Loss: 1.0039 Perceptual Loss: 31.9301
# 200 time: 4:03:03.599874
# PSNR: 16.8682 SSIM: 0.1676
# PSNR: 21.6511 SSIM: 0.1498
