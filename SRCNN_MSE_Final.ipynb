# %%
from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/MIE1516 Project/'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
import cv2
import h5py
import numpy
import math
import skimage
from math import log10, sqrt 
from skimage.metrics import structural_similarity, peak_signal_noise_ratio

# %%
DATA_PATH = root_path + "/DIV2K_train_HR"
LR_DATA_PATH = root_path + "/DIV2K_train_LR_bicubic_X2/"
TEST_PATH = root_path + "/DIV2K_valid_HR/"
SAMPLE_IMAGE_TEST_PATH = root_path + "/DIV2K_valid_HR_sample/"

# %%
import scipy
from skimage import transform, io
import imageio
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
#Link: https://github.com/eriklindernoren/Keras-GAN
class DataLoader():
    def __init__(self, dataset_name, img_res=(128, 128)):
        self.dataset_name = dataset_name
        self.img_res = img_res

    def load_data(self, batch_size=1, is_testing=False, is_random=True):
        data_type = "train" if not is_testing else "test"
        
        path = glob('%s/*' % (self.dataset_name))

        if(is_random == True):
          batch_images = np.random.choice(path, size=batch_size)
        else:
          batch_images = path[0:batch_size]

        imgs_hr = []
        imgs_lr = []
        for img_path in batch_images:
            img = self.imread(img_path)

            h, w = self.img_res
            low_h, low_w = int(h / 4), int(w / 4)

            img_hr = transform.resize(img, self.img_res)
            img_lr = transform.resize(img, (low_h, low_w))

            # If training => do random flip
            if not is_testing and np.random.random() < 0.5:
                img_hr = np.fliplr(img_hr)
                img_lr = np.fliplr(img_lr)

            imgs_hr.append(img_hr)
            imgs_lr.append(img_lr)

        imgs_hr = np.array(imgs_hr) / 127.5 - 1.
        imgs_lr = np.array(imgs_lr) / 127.5 - 1.
        print(imgs_hr.shape)
        print(imgs_lr.shape)
        return imgs_hr, imgs_lr


    def imread(self, path):
        return imageio.imread(path, pilmode='RGB').astype(np.float)

# %%
class ImageMetrics():
  def __init__(self):
    self.name = "Metric for Image"
  
  def print_metrics(self, reference, generated):
    self.reference = (reference)*255.0
    self.generated = (generated)*255.0
    assert self.reference.shape == self.generated.shape
    psnr_score, ssim_score = self.psnr(), self.ssim()
    print("PSNR: %.4f SSIM: %.4f" % (psnr_score, ssim_score))
    return psnr_score, ssim_score

  #Link: https://dsp.stackexchange.com/questions/38065/peak-signal-to-noise-ratio-psnr-in-python-for-an-image
  def psnr(self):
    mse = np.mean((self.reference-self.generated)**2)
    if(mse == 0):
      mse = 100
    MAX_PIXEL = 255.0
    psnr_score = 20*log10(MAX_PIXEL/sqrt(mse))
    return psnr_score

  #Link: https://scikit-image.org/docs/dev/api/skimage.metrics.html#skimage.metrics.structural_similarity
  def ssim(self):
    (ssim_score, difference) = structural_similarity(self.reference, self.generated, multichannel= True, gaussian_weights= True, full=True)
    return ssim_score

# %%
"""
Super-resolution of CelebA using Generative Adversarial Networks.

The dataset can be downloaded from: https://www.dropbox.com/sh/8oqt9vytwxb3s4r/AADIKlz8PR9zr6Y20qbkunrba/Img/img_align_celeba.zip?dl=0

Instrustion on running the script:
1. Download the dataset from the provided link
2. Save the folder 'img_align_celeba' to 'datasets/'
4. Run the sript using command 'python srgan.py'
"""
#Link: https://github.com/eriklindernoren/Keras-GAN
from __future__ import print_function, division
import scipy
# !pip install git+https://www.github.com/keras-team/keras-contrib.git

# %tensorflow_version 1.x
from keras.datasets import mnist
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate
from keras.layers import BatchNormalization, Activation, ZeroPadding2D, Add
from keras.layers.advanced_activations import PReLU, LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.applications import VGG19
from keras.models import Sequential, Model
from keras.optimizers import Adam

import tensorflow as tf
import datetime
import matplotlib.pyplot as plt
import sys
#from data_loader import DataLoader
import numpy as np
import os
from collections import defaultdict
try:
    import cPickle as pickle
except ImportError:
    import pickle

import keras.backend as K


class SRCNN():
    def __init__(self):
        # Input shape
        self.channels = 3
        self.lr_height = 64                 # Low resolution height
        self.lr_width = 64                  # Low resolution width
        self.lr_shape = (self.lr_height, self.lr_width, self.channels)
        self.hr_height = self.lr_height*4   # High resolution height
        self.hr_width = self.lr_width*4     # High resolution width
        self.hr_shape = (self.hr_height, self.hr_width, self.channels)

        # Number of residual blocks in the generator
        self.n_residual_blocks = 16

        optimizer = Adam(0.0002, 0.5)

        # We use a pre-trained VGG19 model to extract image features from the high resolution
        # and the generated high resolution images and minimize the mse between them
        # self.vgg = self.build_vgg()
        # self.vgg.trainable = False
        # self.vgg.compile(loss='mse',
        #     optimizer=optimizer,
        #     metrics=['accuracy'])

        # Configure data loader
        self.save_path_name = root_path
        self.dataset_name = DATA_PATH
        self.test_dataset_name = TEST_PATH
        self.sample_test_dataset_name = SAMPLE_IMAGE_TEST_PATH
        self.data_loader = DataLoader(dataset_name=self.dataset_name,
                                      img_res=(self.hr_height, self.hr_width))
        self.test_data_loader = DataLoader(dataset_name=self.test_dataset_name,
                                      img_res=(self.hr_height, self.hr_width))
        self.sample_test_data_loader = DataLoader(dataset_name=self.sample_test_dataset_name,
                                      img_res=(self.hr_height, self.hr_width))
        self.metrics = ImageMetrics()

        os.makedirs('%s/SRCNN_MSE' % self.save_path_name, exist_ok=True)
        os.makedirs('%s/SRCNN_MSE/checkpoints' % self.save_path_name, exist_ok=True)
        os.makedirs('%s/SRCNN_MSE/sample_image_outputs' % self.save_path_name, exist_ok=True)

        self.model_gen_path = self.save_path_name + "SRCNN_MSE/checkpoints/model_cnn_mse_gen_april12.h5"
        self.sample_images_path = self.save_path_name + "SRCNN_MSE/sample_image_outputs"
        self.history_loss_accuracy_path = self.save_path_name + "SRCNN_MSE/srcnn-mse-history.pkl"

        # Calculate output shape of D (PatchGAN)
        patch = int(self.hr_height / 2**4)
        self.disc_patch = (patch, patch, 1)

        # Number of filters in the first layer of G and D
        self.gf = 64
        self.df = 64

        # Build and compile the discriminator
        # self.discriminator = self.build_discriminator()
        # self.discriminator.compile(loss='mse',
        #     optimizer=optimizer,
        #     metrics=['accuracy'])

        # Build the generator
        self.generator = self.build_generator()

        # High res. and low res. images
        img_hr = Input(shape=self.hr_shape)
        img_lr = Input(shape=self.lr_shape)

       
        self.generator.compile(loss='mse',
                              optimizer=optimizer)


    def build_vgg(self):
        """
        Builds a pre-trained VGG19 model that outputs image features extracted at the
        third block of the model
        """
        vgg = VGG19(weights="imagenet")
        # Set outputs to outputs of last conv. layer in block 3
        # See architecture at: https://github.com/keras-team/keras/blob/master/keras/applications/vgg19.py
        vgg.outputs = [vgg.layers[9].output]

        img = Input(shape=self.hr_shape)

        # Extract image features
        img_features = vgg(img)

        return Model(img, img_features)

    def build_generator(self):

        def residual_block(layer_input, filters):
            """Residual block described in paper"""
            d = Conv2D(filters, kernel_size=3, strides=1, padding='same')(layer_input)
            d = Activation('relu')(d)
            d = BatchNormalization(momentum=0.8)(d)
            d = Conv2D(filters, kernel_size=3, strides=1, padding='same')(d)
            d = BatchNormalization(momentum=0.8)(d)
            d = Add()([d, layer_input])
            return d

        def deconv2d(layer_input):
            """Layers used during upsampling"""
            u = UpSampling2D(size=2)(layer_input)
            u = Conv2D(256, kernel_size=3, strides=1, padding='same')(u)
            u = Activation('relu')(u)
            return u

        # Low resolution image input
        img_lr = Input(shape=self.lr_shape)

        # # Pre-residual block
        # c1 = Conv2D(64, kernel_size=9, strides=1, padding='same')(img_lr)
        # c1 = Activation('relu')(c1)

        # # Propogate through residual blocks
        # r = residual_block(c1, self.gf)
        # for _ in range(self.n_residual_blocks - 1):
        #     r = residual_block(r, self.gf)

        # # Post-residual block
        # c2 = Conv2D(64, kernel_size=3, strides=1, padding='same')(r)
        # c2 = BatchNormalization(momentum=0.8)(c2)
        # c2 = Add()([c2, c1])

        # # Upsampling
        # u1 = deconv2d(c2)
        # u2 = deconv2d(u1)

        # # Generate high resolution output
        # gen_hr = Conv2D(self.channels, kernel_size=9, strides=1, padding='same', activation='tanh')(u2)
        c1 = Conv2D(128, kernel_size=9, strides=1, padding='same')(img_lr)
        c1 = Activation('relu')(c1)
        c2 = Conv2D(64, kernel_size=3, strides=1, padding='same')(c1)
        c2 = Activation('relu')(c2)
        c3 = Conv2D(3, kernel_size=5, strides=1, padding='same')(c2)
        c3 = Activation('linear')(c3)
        u1 = deconv2d(c3)
        u2 = deconv2d(u1)#UpSampling2D(size=4)(c3)
        gen_hr = Conv2D(self.channels, kernel_size=9, strides=1, padding='same', activation='tanh')(u2)
        
        #gen_hr = Reshape(self.hr_shape)

        model_gen = Model(img_lr, gen_hr)
        print(model_gen.summary())
        return model_gen

    def build_discriminator(self):

        def d_block(layer_input, filters, strides=1, bn=True):
            """Discriminator layer"""
            d = Conv2D(filters, kernel_size=3, strides=strides, padding='same')(layer_input)
            d = LeakyReLU(alpha=0.2)(d)
            if bn:
                d = BatchNormalization(momentum=0.8)(d)
            return d

        # Input img
        d0 = Input(shape=self.hr_shape)

        d1 = d_block(d0, self.df, bn=False)
        d2 = d_block(d1, self.df, strides=2)
        d3 = d_block(d2, self.df*2)
        d4 = d_block(d3, self.df*2, strides=2)
        d5 = d_block(d4, self.df*4)
        d6 = d_block(d5, self.df*4, strides=2)
        d7 = d_block(d6, self.df*8)
        d8 = d_block(d7, self.df*8, strides=2)

        d9 = Dense(self.df*16)(d8)
        d10 = LeakyReLU(alpha=0.2)(d9)
        validity = Dense(1, activation='sigmoid')(d10)

        model_disc = Model(d0, validity)
        print(model_disc.summary())
        return model_disc

    def train(self, epochs, batch_size=1, sample_interval=50):

        start_time = datetime.datetime.now()

        if(os.path.exists(self.model_gen_path)):
          print("I am here")
          self.generator.load_weights(self.model_gen_path)

       
        train_dict = defaultdict(list)
        test_dict = defaultdict(list)
        sample_imgs_hr, sample_imgs_lr = self.sample_test_data_loader.load_data(batch_size=2, is_testing=True, is_random=False)
        for epoch in range(epochs):

            # ------------------
            #  Train Generator
            # ------------------

            # Sample images and their conditioning counterparts
            imgs_hr, imgs_lr = self.data_loader.load_data(batch_size)

            # # The generators want the discriminators to label the generated images as real
            # valid = np.ones((batch_size,) + self.disc_patch)

            # Extract ground truth image features using pre-trained VGG19 model
            #image_features = self.vgg.predict(imgs_hr)

            # Train the generators
            g_loss = self.generator.train_on_batch(imgs_lr, imgs_hr)
            print("Training Losses")
            
            print("Generator => Training MSE Loss: %.4f" %(g_loss))
            train_dict["generator"].append(g_loss)

            # ------------------
            #  Test Generator
            # ------------------

            # Sample images and their conditioning counterparts
            imgs_hr, imgs_lr = self.test_data_loader.load_data(batch_size)

           
            # Train the generators
            test_g_loss = self.generator.test_on_batch(imgs_lr, imgs_hr)
            print("Testing Losses")
            
            print("Generator => Testing MSE Loss: %.4f" %(test_g_loss))
            test_dict["generator"].append(test_g_loss)

            elapsed_time = datetime.datetime.now() - start_time
            # Plot the progress
            print ("%d time: %s" % (epoch, elapsed_time))

            self.generator.save_weights(self.model_gen_path)
            
            # If at save interval => save generated image samples
            if epoch % sample_interval == 0:
                self.sample_images(epoch, sample_imgs_hr, sample_imgs_lr)
        
        with open(self.history_loss_accuracy_path, 'wb') as f:
          pickle.dump({'train': train_dict, 'test': test_dict}, f)

    def sample_images(self, epoch, sample_imgs_hr=None, sample_imgs_lr=None):
        #os.makedirs('images/%s' % self.dataset_name, exist_ok=True)
        r, c = 2, 3

        if(sample_imgs_hr is None or sample_imgs_lr is None):
          imgs_hr, imgs_lr = self.test_data_loader.load_data(batch_size=2, is_testing=True)
        else:
          imgs_hr, imgs_lr = sample_imgs_hr,sample_imgs_lr

        fake_hr = self.generator.predict(imgs_lr)

        # Rescale images 0 - 1
        imgs_lr = 0.5 * imgs_lr + 0.5
        fake_hr = 0.5 * fake_hr + 0.5
        imgs_hr = 0.5 * imgs_hr + 0.5

        # Save generated images and the high resolution originals
        titles = ['LR Original','Generated', 'Original']
        fig, axs = plt.subplots(r, c)
        cnt = 0
        for row in range(r):
            psnr_score, ssim_score = self.metrics.print_metrics(reference=imgs_hr[row][2], generated=fake_hr[row][1])
            for col, image in enumerate([imgs_lr, fake_hr, imgs_hr]):
                if(row == 0):
                  if(titles[col] == 'Generated'):
                    col_title = "Generated \n PSNR: %.4f SSIM: %.4f" % (psnr_score, ssim_score)
                  else:
                    col_title = titles[col]+ "\n"
                else:
                  if(titles[col] == 'Generated'):
                    col_title = "PSNR: %.4f SSIM: %.4f" % (psnr_score, ssim_score)
                  else:
                    col_title = "\n"
                axs[row, col].imshow(image[row])
                axs[row, col].set_title(col_title)
                axs[row, col].axis('off')
            cnt += 1
        fig.savefig("%s/%d.png" % (self.sample_images_path, epoch))
        plt.close()

        # Save low resolution images for comparison
        if((epoch == 0 and (sample_imgs_hr is not None or sample_imgs_lr is not None)) or (sample_imgs_hr is None or sample_imgs_lr is None)):
          for i in range(r):
              fig = plt.figure()
              plt.imshow(imgs_lr[i])
              fig.savefig('%s/%d_lowres%d.png' % (self.sample_images_path, epoch, i))
              plt.close()

if __name__ == '__main__':
    tf.reset_default_graph()
    try:
        del srcnn_model
    except:
        pass
    K.clear_session()

    
    graph = tf.get_default_graph()

    with graph.as_default():
      srcnn_model = SRCNN()
      srcnn_model.train(epochs=201, batch_size=10, sample_interval=50)
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-he6eidma
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-he6eidma
# Requirement already satisfied (use --upgrade to upgrade): keras-contrib==2.0.8 from git+https://www.github.com/keras-team/keras-contrib.git in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from keras-contrib==2.0.8) (2.3.1)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (2.10.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->keras-contrib==2.0.8) (1.18.2)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-cp36-none-any.whl size=101064 sha256=c1c207880fbc8a5027a57a390025d20a635fa1bcfb1561b10d127dadc406b237
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dxh5mika/wheels/11/27/c8/4ed56de7b55f4f61244e2dc6ef3cdbaff2692527a2ce6502ba
# Successfully built keras-contrib
# TensorFlow 1.x selected.
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 128)       31232
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        73792
# _________________________________________________________________
# activation_2 (Activation)    (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 3)         4803
# _________________________________________________________________
# activation_3 (Activation)    (None, 64, 64, 3)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 128, 128, 3)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 128, 256)     7168
# _________________________________________________________________
# activation_4 (Activation)    (None, 128, 128, 256)     0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 256, 256, 256)     0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 256, 256, 256)     590080
# _________________________________________________________________
# activation_5 (Activation)    (None, 256, 256, 256)     0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 256, 256, 3)       62211
# =================================================================
# Total params: 769,286
# Trainable params: 769,286
# Non-trainable params: 0
# _________________________________________________________________
# None
# (2, 256, 256, 3)
# (2, 64, 64, 3)
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Training Losses
# Generator => Training MSE Loss: 0.3190
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.2734
# 0 time: 0:00:53.719997
# /usr/local/lib/python3.6/dist-packages/skimage/metrics/_structural_similarity.py:108: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   im2[..., ch], **args)
# PSNR: 9.3048 SSIM: 0.0000
# PSNR: 15.0323 SSIM: -0.0003
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.3673
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.2774
# 1 time: 0:01:38.348221
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.2870
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.2735
# 2 time: 0:02:18.501117
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.2569
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.1614
# 3 time: 0:03:00.878980
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.1731
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.1220
# 4 time: 0:03:42.541838
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.1203
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.1128
# 5 time: 0:04:22.295511
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.1260
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.1027
# 6 time: 0:05:00.275958
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.1200
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.1108
# 7 time: 0:05:41.027479
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.1255
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.1345
# 8 time: 0:06:16.991656
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0882
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0904
# 9 time: 0:06:55.477527
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.1172
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0980
# 10 time: 0:07:34.982834
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.1076
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0934
# 11 time: 0:08:10.318682
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0790
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.1001
# 12 time: 0:08:47.349623
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0841
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.1044
# 13 time: 0:09:25.709641
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0978
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0944
# 14 time: 0:10:02.669606
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.1067
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0640
# 15 time: 0:10:39.343615
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0826
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0735
# 16 time: 0:11:16.373113
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0914
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0767
# 17 time: 0:11:56.077892
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0734
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0595
# 18 time: 0:12:33.454148
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0898
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0755
# 19 time: 0:13:11.027218
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0693
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0670
# 20 time: 0:13:46.525117
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0728
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0493
# 21 time: 0:14:25.182441
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0813
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0710
# 22 time: 0:15:02.463214
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0671
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0556
# 23 time: 0:15:40.320350
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0460
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0744
# 24 time: 0:16:18.084707
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0837
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.1211
# 25 time: 0:16:54.196502
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0870
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0706
# 26 time: 0:17:29.445983
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0813
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0885
# 27 time: 0:18:06.580497
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0758
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0540
# 28 time: 0:18:42.675073
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0566
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0659
# 29 time: 0:19:19.714233
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0573
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0701
# 30 time: 0:19:59.461464
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0613
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0494
# 31 time: 0:20:35.481945
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0635
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0493
# 32 time: 0:21:10.239863
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0667
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0821
# 33 time: 0:21:46.826716
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0572
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0532
# 34 time: 0:22:24.155195
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0750
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0749
# 35 time: 0:23:00.687045
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0688
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0531
# 36 time: 0:23:38.018180
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0659
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0508
# 37 time: 0:24:11.547576
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0536
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0505
# 38 time: 0:24:47.339661
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0448
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0441
# 39 time: 0:25:24.110043
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0637
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0521
# 40 time: 0:26:00.438443
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0503
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0682
# 41 time: 0:26:37.926475
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0518
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0503
# 42 time: 0:27:15.341057
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0411
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0676
# 43 time: 0:27:54.601084
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0543
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0588
# 44 time: 0:28:31.857178
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0444
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0525
# 45 time: 0:29:07.057765
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0529
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0383
# 46 time: 0:29:44.609813
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0458
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0469
# 47 time: 0:30:20.880421
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0596
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0595
# 48 time: 0:30:56.727210
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0545
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0427
# 49 time: 0:31:33.097250
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0333
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0574
# 50 time: 0:32:10.748066
# PSNR: 16.1123 SSIM: 0.0056
# PSNR: 18.0105 SSIM: 0.0487
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0491
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0482
# 51 time: 0:32:48.004914
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0542
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0434
# 52 time: 0:33:23.382518
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0564
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0408
# 53 time: 0:34:01.432384
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0463
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0494
# 54 time: 0:34:40.397824
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0443
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0460
# 55 time: 0:35:17.955889
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0427
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0429
# 56 time: 0:35:56.831900
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0622
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0542
# 57 time: 0:36:33.569724
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0564
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0601
# 58 time: 0:37:08.920065
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0549
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0557
# 59 time: 0:37:46.874903
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0469
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0699
# 60 time: 0:38:25.455286
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0484
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0573
# 61 time: 0:39:04.601243
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0471
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0582
# 62 time: 0:39:41.213199
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0599
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0514
# 63 time: 0:40:19.366962
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0393
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0372
# 64 time: 0:40:57.767945
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0406
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0466
# 65 time: 0:41:36.552404
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0549
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0473
# 66 time: 0:42:14.015316
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0484
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0531
# 67 time: 0:42:53.800020
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0411
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0488
# 68 time: 0:43:29.800855
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0461
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0438
# 69 time: 0:44:05.876625
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0545
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0388
# 70 time: 0:44:38.962412
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0432
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0421
# 71 time: 0:45:15.831240
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0632
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0331
# 72 time: 0:45:54.908020
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0473
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0426
# 73 time: 0:46:29.756615
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0402
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0678
# 74 time: 0:47:04.348986
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0501
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0461
# 75 time: 0:47:42.236734
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0532
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0480
# 76 time: 0:48:19.815253
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0443
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0670
# 77 time: 0:48:53.806048
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0458
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0455
# 78 time: 0:49:28.913737
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0413
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0529
# 79 time: 0:50:03.797361
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0500
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0430
# 80 time: 0:50:38.738656
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0562
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0503
# 81 time: 0:51:14.926252
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0417
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0416
# 82 time: 0:51:49.855104
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0404
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0416
# 83 time: 0:52:26.503290
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0503
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0437
# 84 time: 0:53:03.776056
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0554
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0458
# 85 time: 0:53:39.743195
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0382
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0386
# 86 time: 0:54:20.088747
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0449
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0490
# 87 time: 0:55:05.340163
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0402
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0458
# 88 time: 0:55:42.132589
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0404
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0393
# 89 time: 0:56:16.947394
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0311
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0322
# 90 time: 0:56:52.658384
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0406
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0359
# 91 time: 0:57:26.430949
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0349
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0348
# 92 time: 0:58:00.501157
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0361
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0361
# 93 time: 0:58:36.088220
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0439
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0355
# 94 time: 0:59:09.958359
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0424
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0255
# 95 time: 0:59:46.291055
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0488
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0392
# 96 time: 1:00:20.054134
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0307
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0402
# 97 time: 1:00:56.188164
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0493
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0456
# 98 time: 1:01:28.652769
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0376
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0331
# 99 time: 1:02:02.915644
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0336
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0302
# 100 time: 1:02:36.121581
# PSNR: 16.9409 SSIM: 0.0332
# PSNR: 18.2812 SSIM: 0.0562
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0331
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0452
# 101 time: 1:03:11.855855
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0303
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0367
# 102 time: 1:03:45.805747
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0416
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0500
# 103 time: 1:04:21.244511
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0403
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0468
# 104 time: 1:04:54.223953
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0478
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0401
# 105 time: 1:05:27.871160
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0585
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0403
# 106 time: 1:06:03.715425
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0440
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0595
# 107 time: 1:06:38.351323
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0323
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0524
# 108 time: 1:07:12.832648
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0394
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0309
# 109 time: 1:07:47.215608
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0358
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0413
# 110 time: 1:08:20.708220
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0365
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0450
# 111 time: 1:08:56.417116
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0352
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0453
# 112 time: 1:09:31.409391
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0346
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0349
# 113 time: 1:10:05.119047
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0434
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0311
# 114 time: 1:10:39.705858
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0281
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0267
# 115 time: 1:11:17.944105
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0375
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0313
# 116 time: 1:11:53.107151
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0336
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0399
# 117 time: 1:12:27.964891
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0360
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0363
# 118 time: 1:13:03.346018
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0336
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0284
# 119 time: 1:13:37.070366
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0395
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0340
# 120 time: 1:14:12.085483
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0417
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0333
# 121 time: 1:14:44.801643
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0352
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0493
# 122 time: 1:15:19.533583
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0430
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0365
# 123 time: 1:15:54.091315
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0298
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0282
# 124 time: 1:16:28.592881
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0368
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0339
# 125 time: 1:17:04.031516
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0284
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0317
# 126 time: 1:17:39.092388
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0282
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0320
# 127 time: 1:18:15.018509
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0391
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0332
# 128 time: 1:18:50.145644
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0388
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0405
# 129 time: 1:19:26.098126
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0389
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0460
# 130 time: 1:20:01.863436
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0500
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0596
# 131 time: 1:20:36.046359
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0511
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0494
# 132 time: 1:21:13.347324
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0576
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0640
# 133 time: 1:21:48.335325
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0479
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0436
# 134 time: 1:22:21.932136
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0577
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0438
# 135 time: 1:22:56.686435
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0511
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0398
# 136 time: 1:23:31.244465
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0432
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0388
# 137 time: 1:24:07.162777
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0546
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0470
# 138 time: 1:24:42.890613
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0569
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0302
# 139 time: 1:25:17.620013
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0404
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0443
# 140 time: 1:25:53.336131
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0286
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0322
# 141 time: 1:26:29.088189
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0326
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0231
# 142 time: 1:27:04.049442
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0321
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0262
# 143 time: 1:27:39.215273
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0437
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0328
# 144 time: 1:28:13.097575
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0384
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0309
# 145 time: 1:28:49.144698
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0319
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0333
# 146 time: 1:29:23.753217
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0374
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0445
# 147 time: 1:29:59.594016
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0395
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0288
# 148 time: 1:30:38.607801
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0318
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0285
# 149 time: 1:31:13.381905
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0362
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0348
# 150 time: 1:31:48.293333
# PSNR: 19.3325 SSIM: 0.0671
# PSNR: 18.1250 SSIM: 0.0612
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0380
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0368
# 151 time: 1:32:23.816710
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0410
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0403
# 152 time: 1:32:57.887964
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0267
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0338
# 153 time: 1:33:33.620773
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0373
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0390
# 154 time: 1:34:08.922630
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0350
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0442
# 155 time: 1:34:43.908344
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0392
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0332
# 156 time: 1:35:20.902961
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0305
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0277
# 157 time: 1:35:56.302641
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0312
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0338
# 158 time: 1:36:31.012021
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0341
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0315
# 159 time: 1:37:08.251452
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0219
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0369
# 160 time: 1:37:40.673502
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0335
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0316
# 161 time: 1:38:17.089298
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0319
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0314
# 162 time: 1:38:51.928472
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0321
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0309
# 163 time: 1:39:28.237684
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0346
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0336
# 164 time: 1:40:04.359192
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0277
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0356
# 165 time: 1:40:39.961750
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0273
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0293
# 166 time: 1:41:15.647855
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0301
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0465
# 167 time: 1:41:51.494208
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0388
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0450
# 168 time: 1:42:27.438658
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0486
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0336
# 169 time: 1:43:00.883833
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0317
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0555
# 170 time: 1:43:35.365043
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0341
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0249
# 171 time: 1:44:07.913419
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0292
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0494
# 172 time: 1:44:40.910881
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0369
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0260
# 173 time: 1:45:16.426509
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0365
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0310
# 174 time: 1:45:53.490304
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0331
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0315
# 175 time: 1:46:27.365383
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0296
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0332
# 176 time: 1:47:03.234653
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0304
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0364
# 177 time: 1:47:37.272558
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0336
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0316
# 178 time: 1:48:13.980800
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0301
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0302
# 179 time: 1:48:48.222499
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0394
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0451
# 180 time: 1:49:22.244648
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0299
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0213
# 181 time: 1:49:57.878312
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0241
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0285
# 182 time: 1:50:32.317646
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0276
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0353
# 183 time: 1:51:07.521899
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0365
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0284
# 184 time: 1:51:42.551560
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0316
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0323
# 185 time: 1:52:17.440762
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0288
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0348
# 186 time: 1:52:52.908353
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0309
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0344
# 187 time: 1:53:29.355433
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0297
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0226
# 188 time: 1:54:05.960651
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0320
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0253
# 189 time: 1:54:40.552228
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0224
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0257
# 190 time: 1:55:19.148769
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0300
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0356
# 191 time: 1:55:55.597933
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0249
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0297
# 192 time: 1:56:33.453939
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0238
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0261
# 193 time: 1:57:09.836287
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0236
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0311
# 194 time: 1:57:46.081138
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0259
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0411
# 195 time: 1:58:20.967738
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0213
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0288
# 196 time: 1:58:56.366785
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0329
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0361
# 197 time: 1:59:32.918288
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0291
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0327
# 198 time: 2:00:09.237899
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0279
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0290
# 199 time: 2:00:43.980900
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Training Losses
# Generator => Training MSE Loss: 0.0302
# (10, 256, 256, 3)
# (10, 64, 64, 3)
# Testing Losses
# Generator => Testing MSE Loss: 0.0321
# 200 time: 2:01:18.506445
# PSNR: 20.3921 SSIM: 0.0952
# PSNR: 18.4688 SSIM: 0.0801
